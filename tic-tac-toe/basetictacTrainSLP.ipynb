# %%
from google.colab import drive
drive.mount('/content/drive')
import shutil

# Copy the file to Google Drive
shutil.copy('/content/drive/My Drive/tic_tac_toe_dataset.npz', 'tic_tac_toe_dataset.npz')
# Out:
# Mounted at /content/drive
# 'tic_tac_toe_dataset.npz'

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
# Load the dataset
data = np.load('tic_tac_toe_dataset.npz')
X = data['X']
y = data['y']

# Flatten the input data to make it suitable for the perceptron (each row is a flattened 3x3 board)
X_flat = X.reshape(X.shape[0], -1)

# Split the data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X_flat, y, test_size=0.2, random_state=42)

# Define the model (the model consists of one Dense layer with 9 output units and a softmax activation function)
model = Sequential()
model.add(Dense(9, input_shape=(X_flat.shape[1],), activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.01), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model (the model is trained on the training data for 50 epochs with a batch size of 32 and a validation split of 10%)
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)
accuracy = accuracy_score(y_test_classes, y_pred_classes)

print(f"Test accuracy: {accuracy * 100:.2f}%")

# Save the trained model
# model.save('tic_tac_toe_model.h5')
# Out:
# Epoch 1/50
# 149/149 [==============================] - 2s 7ms/step - loss: 2.1300 - accuracy: 0.1938 - val_loss: 2.0806 - val_accuracy: 0.1981
# Epoch 2/50
# 149/149 [==============================] - 1s 5ms/step - loss: 2.0440 - accuracy: 0.2438 - val_loss: 2.0850 - val_accuracy: 0.2264
# Epoch 3/50
# 149/149 [==============================] - 1s 5ms/step - loss: 2.0425 - accuracy: 0.2564 - val_loss: 2.0800 - val_accuracy: 0.2132
# Epoch 4/50
# 149/149 [==============================] - 1s 3ms/step - loss: 2.0414 - accuracy: 0.2509 - val_loss: 2.0810 - val_accuracy: 0.2000
# Epoch 5/50
# 149/149 [==============================] - 1s 4ms/step - loss: 2.0421 - accuracy: 0.2410 - val_loss: 2.0773 - val_accuracy: 0.2245
# Epoch 6/50
# 149/149 [==============================] - 1s 4ms/step - loss: 2.0423 - accuracy: 0.2547 - val_loss: 2.0767 - val_accuracy: 0.2358
# Epoch 7/50
# 149/149 [==============================] - 1s 3ms/step - loss: 2.0433 - accuracy: 0.2446 - val_loss: 2.0843 - val_accuracy: 0.2057
# Epoch 8/50
# 149/149 [==============================] - 1s 4ms/step - loss: 2.0414 - accuracy: 0.2511 - val_loss: 2.0842 - val_accuracy: 0.2113
# Epoch 9/50
# 149/149 [==============================] - 1s 5ms/step - loss: 2.0425 - accuracy: 0.2580 - val_loss: 2.0825 - val_accuracy: 0.2094
# Epoch 10/50
# 149/149 [==============================] - 1s 5ms/step - loss: 2.0426 - accuracy: 0.2564 - val_loss: 2.0820 - val_accuracy: 0.2132
# Epoch 11/50
# 149/149 [==============================] - 1s 4ms/step - loss: 2.0424 - accuracy: 0.2524 - val_loss: 2.0775 - val_accuracy: 0.2075
# Epoch 12/50
# 149/149 [==============================] - 1s 4ms/step - loss: 2.0419 - accuracy: 0.2515 - val_loss: 2.0884 - val_accuracy: 0.2170
# Epoch 13/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0418 - accuracy: 0.2503 - val_loss: 2.0864 - val_accuracy: 0.2075
# Epoch 33/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0416 - accuracy: 0.2484 - val_loss: 2.0795 - val_accuracy: 0.2151
# Epoch 34/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0418 - accuracy: 0.2480 - val_loss: 2.0826 - val_accuracy: 0.2170
# Epoch 35/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0420 - accuracy: 0.2522 - val_loss: 2.0808 - val_accuracy: 0.1981
# Epoch 36/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0416 - accuracy: 0.2503 - val_loss: 2.0784 - val_accuracy: 0.2245
# Epoch 37/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0418 - accuracy: 0.2534 - val_loss: 2.0791 - val_accuracy: 0.2094
# Epoch 38/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0417 - accuracy: 0.2517 - val_loss: 2.0833 - val_accuracy: 0.2151
# Epoch 39/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0423 - accuracy: 0.2473 - val_loss: 2.0785 - val_accuracy: 0.2283
# Epoch 40/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0418 - accuracy: 0.2551 - val_loss: 2.0815 - val_accuracy: 0.2094
# Epoch 41/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0415 - accuracy: 0.2536 - val_loss: 2.0805 - val_accuracy: 0.2132
# Epoch 42/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0414 - accuracy: 0.2503 - val_loss: 2.0843 - val_accuracy: 0.2208
# Epoch 43/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0417 - accuracy: 0.2501 - val_loss: 2.0755 - val_accuracy: 0.2226
# Epoch 44/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0422 - accuracy: 0.2540 - val_loss: 2.0768 - val_accuracy: 0.2132
# Epoch 45/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0433 - accuracy: 0.2494 - val_loss: 2.0813 - val_accuracy: 0.2151
# Epoch 46/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0421 - accuracy: 0.2551 - val_loss: 2.0772 - val_accuracy: 0.2321
# Epoch 47/50
# 149/149 [==============================] - 0s 3ms/step - loss: 2.0442 - accuracy: 0.2505 - val_loss: 2.0788 - val_accuracy: 0.2113
# Epoch 48/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0416 - accuracy: 0.2484 - val_loss: 2.0800 - val_accuracy: 0.2189
# Epoch 49/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0425 - accuracy: 0.2553 - val_loss: 2.0795 - val_accuracy: 0.2189
# Epoch 50/50
# 149/149 [==============================] - 0s 2ms/step - loss: 2.0413 - accuracy: 0.2503 - val_loss: 2.0790 - val_accuracy: 0.2113
# 42/42 [==============================] - 0s 2ms/step
# Test accuracy: 26.96%
