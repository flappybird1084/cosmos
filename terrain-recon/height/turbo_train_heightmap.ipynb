# %%
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd# import everything ml
import torch
from torch.utils.data import DataLoader, TensorDataset
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn.functional as F
import pandas as pd
import re
import string
from wordcloud import WordCloud
import nltk
from collections import Counter
import contractions
from tqdm import tqdm
import math
from torch.utils.data import Dataset, DataLoader
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import os
from PIL import Image, ImageFile
import torchvision.models as models
from PIL import ImageDraw
import datasets
from datasets import load_dataset
from torch.utils.data import random_split

# %%
class DoubleConv(nn.Module):
    def __init__(self, out_channels):
        super(DoubleConv, self).__init__()
        self.conv = nn.Sequential(
            nn.LazyConv2d(out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.LazyConv2d(out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class UNet(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, features=[64, 128, 256, 512], use_sigmoid=True):
        self.use_sigmoid = use_sigmoid
        
        super(UNet, self).__init__()
        self.encoder = nn.ModuleList()
        self.decoder = nn.ModuleList()
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

        # Encoder
        for feature in features:
            self.encoder.append(DoubleConv(feature))

        # Bottleneck
        self.bottleneck = DoubleConv(features[-1] * 2)

        # Decoder
        for feature in reversed(features):
            self.decoder.append(nn.ConvTranspose2d(feature * 2, feature, kernel_size=2, stride=2))
            self.decoder.append(DoubleConv(feature))  # after concatenation

        self.final_conv = nn.Conv2d(features[0], out_channels, kernel_size=1)
        self.output_activation = nn.Sigmoid() if out_channels == 1 else nn.Identity()
    def forward(self, x):
        skip_connections = []

        for layer in self.encoder:
            x = layer(x)
            skip_connections.append(x)
            x = self.pool(x)

        x = self.bottleneck(x)
        skip_connections = skip_connections[::-1]

        for idx in range(0, len(self.decoder), 2):
            x = self.decoder[idx](x)  # upsample
            skip_connection = skip_connections[idx // 2]
            if x.shape != skip_connection.shape:
                x = F.interpolate(x, size=skip_connection.shape[2:], mode='bilinear', align_corners=True)
            x = torch.cat((skip_connection, x), dim=1)  # concat
            x = self.decoder[idx + 1](x)  # double conv

        # return self.final_conv(x)
        if(self.use_sigmoid):
            return self.output_activation(self.final_conv(x))
        else:
            return self.final_conv(x)

# %%
# Dataset path
dataset_path = './data/terrain_reconstruction/_dataset'

all_files = os.listdir(dataset_path)
print(f"Found {len(all_files)} files")
print("First 5 files:", all_files[:5])

# # Define dataset class
# class TerrainDataset(Dataset):
#     def __init__(self, data_dir, image_type, transform=None):
#         self.data_dir = data_dir
#         self.transform = transform
#         self.image_paths = [
#             os.path.join(data_dir, f) for f in os.listdir(data_dir) if image_type in f
#         ]
#         print(f"Found {len(self.image_paths)} '{image_type}' images in {data_dir}")
#         # self.labels = [
#         #     int(os.path.basename(f).split('_')[0]) for f in self.image_paths
#         # ]

#     def __len__(self):
#         return len(self.image_paths)

#     def __getitem__(self, idx):
#         image = Image.open(self.image_paths[idx]).convert('RGB')
#         # label = self.labels[idx]
#         if self.transform:
#             image = self.transform(image)
#         return image

# Define transform
transform_pipeline = transforms.Compose([
    transforms.Resize((128,128)),
    transforms.ToTensor(),
    # transforms.Normalize(mean=[0.5], std=[0.5]),
    # transforms.Normalize(mean=[0.485, 0.456, 0.406],
    #                      std=[0.229, 0.224, 0.225])
])

# class TerrainDataset(Dataset):
#     def __init__(self, data_dir, transform=None):
#         self.data_dir = data_dir
#         self.transform = transform
#         self.image_types = ['h', 't', 'i']  # heightmap, terrain, segmentation
#         self.image_paths_height = [
#             os.path.join(data_dir, f) for f in os.listdir(data_dir) if 'h' in f
#         ]
#         self.image_paths_terrain = [
#             os.path.join(data_dir, f) for f in os.listdir(data_dir) if 't' in f
#         ]
#         self.image_paths_segmentation = [
#             os.path.join(data_dir, f) for f in os.listdir(data_dir) if 'i' in f
#         ]
#         self.image_paths = self.image_paths_height + self.image_paths_terrain + self.image_paths_segmentation
#         print(f"Found {len(self.image_paths)}  images in {data_dir}")

#     def __len__(self):
#         return len(self.image_paths)

#     def __getitem__(self, idx):
#         # image = Image.open(self.image_paths[idx]).convert('RGB')
#         # if self.transform:
#         #     image = self.transform(image)
#         # return image
#         images = []
#         for image_type in [self.image_paths_height, self.image_paths_terrain, self.image_paths_segmentation]:
#            image = Image.open(image_type[idx]).convert('RGB')
#            if self.transform:
#                image = self.transform(image)
#            images.append(image)
#         return images  # Return a tuple of (heightmap, terrain, segmentation) 
class TerrainDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.transform = transform

        # Sort to ensure alignment between h, t, i files
        self.height_paths = sorted(
            [os.path.join(data_dir, f) for f in os.listdir(data_dir) if '_h' in f]
        )
        self.terrain_paths = sorted(
            [os.path.join(data_dir, f) for f in os.listdir(data_dir) if '_t' in f]
        )
        self.segmentation_paths = sorted(
            [os.path.join(data_dir, f) for f in os.listdir(data_dir) if '_i' in f or '_i2' in f]
        )

        assert len(self.height_paths) == len(self.terrain_paths) == len(self.segmentation_paths), \
            "Mismatch in dataset triplet lengths"

        print(f"Found {len(self.height_paths)} triplets in {data_dir}")

    def __len__(self):
        return len(self.height_paths)

    def __getitem__(self, idx):
        # Load heightmap, terrain, segmentation
        paths = [self.height_paths[idx], self.terrain_paths[idx], self.segmentation_paths[idx]]
        images = []
        for path in paths:
            # image = Image.open(path).convert('RGB')
            image = Image.open(path)
            if self.transform:
                image = self.transform(image)
            images.append(image)
        return tuple(images)  # (heightmap, terrain, segmentation)
# # Use the correct variable in dataset
# heightmap_dataset = TerrainDataset(dataset_path, 'h', transform=transform_pipeline)
# terrain_dataset = TerrainDataset(dataset_path, 't', transform=transform_pipeline)
# segmentation_dataset = TerrainDataset(dataset_path, 'i', transform=transform_pipeline)
dataset = TerrainDataset(dataset_path, transform=transform_pipeline)

# Example: 80% train, 20% test
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
dataset_train, dataset_test= random_split(dataset, [train_size, test_size])

# # Do the same for terrain and segmentation
# terrain_train, terrain_test = random_split(terrain_dataset, [train_size, test_size])
# segmentation_train, segmentation_test = random_split(segmentation_dataset, [train_size, test_size])


# Function to show a normalized image
def show_tensor_image(tensor_img, title=""):
    # # De-normalize
    # mean = torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)
    # std = torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1)
    # img = tensor_img * std + mean
    # img = img.clamp(0, 1).permute(1, 2, 0).numpy()
    img = tensor_img.permute(1, 2, 0).numpy()  # Convert to HWC format
    
    # Plot
    plt.figure(figsize=(4, 4))
    plt.imshow(img)
    plt.title(title)
    plt.axis('off')
    plt.show()

# Show sample image from terrain dataset
# print(len(dataset_train))
# image = next(iter(dataset_train))
# show_tensor_image(image, title="Sample Terrain Image")
sample = dataset_train[0]
heightmap, terrain, segmentation = sample  # unpack tuple

show_tensor_image(terrain, title="Sample Terrain Image")
show_tensor_image(heightmap, title="Sample Heightmap Image")
show_tensor_image(segmentation, title="Sample Segmentation Image")
# Out:
# Found 15000 files
# First 5 files: ['2718_i2.png', '3184_t.png', '0080_i2.png', '2806_h.png', '0689_i2.png']
# Found 5000 triplets in ./data/terrain_reconstruction/_dataset

# %%
# from unet import UNet
device = torch.device("mps" if torch.backends.mps.is_available() else "cuda" if torch.cuda.is_available() else "cpu")

#initialize dataloaders
numworkers=16
batchsize =8
# heightmap_loader = DataLoader(heightmap_dataset, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# terrain_loader = DataLoader(terrain_dataset, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# # segmentation_loader = DataLoader(segmentation_dataset, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# heightmap_train_loader = DataLoader(heightmap_train, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# heightmap_test_loader = DataLoader(heightmap_test, batch_size=batchsize, shuffle=False, num_workers=numworkers)
# terrain_train_loader = DataLoader(terrain_train, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# terrain_test_loader = DataLoader(terrain_test, batch_size=batchsize, shuffle=False, num_workers=numworkers)
# segmentation_train_loader = DataLoader(segmentation_train, batch_size=batchsize, shuffle=True, num_workers=numworkers)
# segmentation_test_loader = DataLoader(segmentation_test, batch_size=batchsize, shuffle=False, num_workers=numworkers)
train_loader = DataLoader(dataset_train, batch_size=batchsize, shuffle=True, num_workers=numworkers)
test_loader = DataLoader(dataset_test, batch_size=batchsize, shuffle=False, num_workers=numworkers)


class PerceptualLoss(nn.Module):
    def __init__(self, feature_layer=9):
        super(PerceptualLoss, self).__init__()
        vgg = models.vgg16(weights=models.VGG16_Weights.DEFAULT).features[:feature_layer].eval()
        for param in vgg.parameters():
            param.requires_grad = False
        self.vgg = vgg.to(device)
        self.transform = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                              std=[0.229, 0.224, 0.225])
    def forward(self, pred, target):
        pred = self.transform(pred)
        target = self.transform(target)
        return nn.functional.mse_loss(self.vgg(pred), self.vgg(target))

def total_variation_loss(x):
    return torch.mean(torch.abs(x[:, :, :, :-1] - x[:, :, :, 1:])) + \
           torch.mean(torch.abs(x[:, :, :-1, :] - x[:, :, 1:, :]))


# Initialize UNet model
unet_model = UNet(in_channels=3, out_channels=1, use_sigmoid=False, features=[64,128,256,512, 1024]).to(device)
# criterion = nn.MSELoss()
# optimizer = optim.Adam(unet_model.parameters(), lr=0.001)

mse_loss = nn.MSELoss()
perceptual_loss = PerceptualLoss().to(device)
perceptual_loss_scaling_factor = 0.1  # Adjust this factor based on your needs
optimizer = optim.Adam(unet_model.parameters(), lr=0.001)

# %%
# num_epochs = 2
# for epoch in range(num_epochs):
#     unet_model.train()
#     running_loss = 0.0
    
#     for i, (images) in enumerate(train_loader):
#         images = images.to(device)
        
#         # Forward pass
#         outputs = unet_model(images)
#         loss = criterion(outputs, images)
#         running_loss += loss.item()
#         # Backward pass and optimization
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
#         if (i + 1) % 10 == 0:
#             print(f'Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}')

# unet_model.load_state_dict(torch.load('./models/terrain/heightmap_unet_model.pth'))
num_epochs = 50
for epoch in range(num_epochs):
    unet_model.train()
    running_loss = 0.0
    
    for i, (height, terrain, segmentation) in enumerate(train_loader):
        images = segmentation
        images = images.to(device).float()
        target_images = height
        target_images = target_images.to(device).float()
        
        # Forward pass
        outputs = unet_model(images)
        # print(f"Outputs shape: {outputs.shape}, Target shape: {target_images.shape}")
        # print(f"outputs {outputs}")
        # print(f"target_images {target_images}")
        # loss = criterion(outputs, target_images)
            # Convert [B, 1, H, W] → [B, 3, H, W]

        outputs_rgb = outputs.repeat(1, 3, 1, 1)
        targets_rgb = target_images.repeat(1, 3, 1, 1)
            # loss = mse_loss(outputs/65535, target_images/65535) + perceptual_loss(outputs/65535, target_images/65535) * perceptual_loss_scaling_factor
        tv_weight = 1e-6 
        loss = ( mse_loss(outputs/65535, target_images/65535) + perceptual_loss_scaling_factor *
        perceptual_loss(outputs_rgb/65535, targets_rgb/65535)+ tv_weight * total_variation_loss(outputs/65535) )
        #TODO: ADD PERCEPTUAL LOSS
        running_loss += loss.item()
        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (i + 1) % 10 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], Step [{i + 1}/{len(train_loader)}], Loss: {loss.item():.4f}')

torch.save(unet_model.state_dict(), './models/terrain/turbo_heightmap_unet_model.pth')
print("Model saved to './models/terrain/turbo_heightmap_unet_model.pth'")
# Out:
# Epoch [1/50], Step [10/500], Loss: 0.1631
# Epoch [1/50], Step [20/500], Loss: 0.7900
# Epoch [1/50], Step [30/500], Loss: 0.2110
# Epoch [1/50], Step [40/500], Loss: 0.1314
# Epoch [1/50], Step [50/500], Loss: 0.2112
# Epoch [1/50], Step [60/500], Loss: 0.8165
# Epoch [1/50], Step [70/500], Loss: 0.2682
# Epoch [1/50], Step [80/500], Loss: 0.1547
# Epoch [1/50], Step [90/500], Loss: 0.6896
# Epoch [1/50], Step [100/500], Loss: 0.1228
# Epoch [1/50], Step [110/500], Loss: 0.6624
# Epoch [1/50], Step [120/500], Loss: 0.1075
# Epoch [1/50], Step [130/500], Loss: 0.1214
# Epoch [1/50], Step [140/500], Loss: 0.9882
# Epoch [1/50], Step [150/500], Loss: 0.7813
# Epoch [1/50], Step [160/500], Loss: 0.1702
# Epoch [1/50], Step [170/500], Loss: 0.4700
# Epoch [1/50], Step [180/500], Loss: 0.6002
# Epoch [1/50], Step [190/500], Loss: 0.1364
# Epoch [1/50], Step [200/500], Loss: 0.4974
# Epoch [1/50], Step [210/500], Loss: 0.3043
# Epoch [1/50], Step [220/500], Loss: 0.6140
# Epoch [1/50], Step [230/500], Loss: 0.0947
# Epoch [1/50], Step [240/500], Loss: 0.1243
# Epoch [1/50], Step [250/500], Loss: 0.0804
# Epoch [1/50], Step [260/500], Loss: 0.0966
# Epoch [1/50], Step [270/500], Loss: 0.1484
# Epoch [1/50], Step [280/500], Loss: 0.1205
# Epoch [1/50], Step [290/500], Loss: 0.0837
# Epoch [1/50], Step [300/500], Loss: 0.1760
# Epoch [1/50], Step [310/500], Loss: 0.1141
# Epoch [1/50], Step [320/500], Loss: 0.9905
# Epoch [1/50], Step [330/500], Loss: 0.1110
# Epoch [1/50], Step [340/500], Loss: 0.1105
# Epoch [1/50], Step [350/500], Loss: 0.1255
# Epoch [1/50], Step [360/500], Loss: 0.5935
# Epoch [1/50], Step [370/500], Loss: 0.7451
# Epoch [1/50], Step [380/500], Loss: 0.4759
# Epoch [1/50], Step [390/500], Loss: 0.2295
# Epoch [1/50], Step [400/500], Loss: 0.9068
# Epoch [1/50], Step [410/500], Loss: 0.0945
# Epoch [1/50], Step [420/500], Loss: 0.1959
# Epoch [1/50], Step [430/500], Loss: 0.5744
# Epoch [1/50], Step [440/500], Loss: 0.7143
# Epoch [1/50], Step [450/500], Loss: 0.1412
# Epoch [1/50], Step [460/500], Loss: 0.1109
# Epoch [1/50], Step [470/500], Loss: 0.0762
# Epoch [1/50], Step [480/500], Loss: 0.1300
# Epoch [1/50], Step [490/500], Loss: 0.1826
# Epoch [1/50], Step [500/500], Loss: 0.7842
# Epoch [2/50], Step [10/500], Loss: 0.0959
# Epoch [2/50], Step [20/500], Loss: 0.4106
# Epoch [2/50], Step [30/500], Loss: 0.1715
# Epoch [2/50], Step [40/500], Loss: 0.0844
# Epoch [2/50], Step [50/500], Loss: 0.3026
# Epoch [2/50], Step [60/500], Loss: 0.2720
# Epoch [2/50], Step [70/500], Loss: 0.0791
# Epoch [2/50], Step [80/500], Loss: 0.3922
# Epoch [2/50], Step [90/500], Loss: 0.2322
# Epoch [2/50], Step [100/500], Loss: 0.6042
# Epoch [2/50], Step [110/500], Loss: 0.1910
# Epoch [2/50], Step [120/500], Loss: 0.1380
# Epoch [2/50], Step [130/500], Loss: 0.0734
# Epoch [2/50], Step [140/500], Loss: 0.4934
# Epoch [2/50], Step [150/500], Loss: 0.2914
# Epoch [2/50], Step [160/500], Loss: 0.1197
# Epoch [2/50], Step [170/500], Loss: 0.3456
# Epoch [2/50], Step [180/500], Loss: 0.0880
# Epoch [2/50], Step [190/500], Loss: 0.0831
# Epoch [2/50], Step [200/500], Loss: 0.1066
# Epoch [2/50], Step [210/500], Loss: 0.1573
# Epoch [2/50], Step [220/500], Loss: 0.0791
# Epoch [2/50], Step [230/500], Loss: 0.5976
# Epoch [2/50], Step [240/500], Loss: 0.0818
# Epoch [2/50], Step [250/500], Loss: 0.1019
# Epoch [2/50], Step [260/500], Loss: 0.2857
# Epoch [2/50], Step [270/500], Loss: 0.3979
# Epoch [2/50], Step [280/500], Loss: 0.1842
# Epoch [2/50], Step [290/500], Loss: 0.1208
# Epoch [2/50], Step [300/500], Loss: 0.7375
# Epoch [2/50], Step [310/500], Loss: 0.0959
# Epoch [2/50], Step [320/500], Loss: 0.3879
# Epoch [2/50], Step [330/500], Loss: 0.1015
# Epoch [2/50], Step [340/500], Loss: 0.1317
# Epoch [2/50], Step [350/500], Loss: 0.1394
# Epoch [2/50], Step [360/500], Loss: 0.4887
# Epoch [2/50], Step [370/500], Loss: 0.5896
# Epoch [2/50], Step [380/500], Loss: 0.0886
# Epoch [2/50], Step [390/500], Loss: 0.5722
# Epoch [2/50], Step [400/500], Loss: 0.0768
# Epoch [2/50], Step [410/500], Loss: 0.6067
# Epoch [2/50], Step [420/500], Loss: 0.0922
# Epoch [2/50], Step [430/500], Loss: 0.8619
# Epoch [2/50], Step [440/500], Loss: 0.1038
# Epoch [2/50], Step [450/500], Loss: 0.0995
# Epoch [2/50], Step [460/500], Loss: 0.7368
# Epoch [2/50], Step [470/500], Loss: 1.5358
# Epoch [2/50], Step [480/500], Loss: 0.2818
# Epoch [2/50], Step [490/500], Loss: 0.0666
# Epoch [2/50], Step [500/500], Loss: 0.1067
# Epoch [3/50], Step [10/500], Loss: 0.5122
# Epoch [3/50], Step [20/500], Loss: 0.1264
# Epoch [3/50], Step [30/500], Loss: 0.0910
# Epoch [3/50], Step [40/500], Loss: 0.1247
# Epoch [3/50], Step [50/500], Loss: 0.6415
# Epoch [3/50], Step [60/500], Loss: 0.9168
# Epoch [3/50], Step [70/500], Loss: 0.7244
# Epoch [3/50], Step [80/500], Loss: 0.2836
# Epoch [3/50], Step [90/500], Loss: 0.2106
# Epoch [3/50], Step [100/500], Loss: 0.3050
# Epoch [3/50], Step [110/500], Loss: 0.1029
# Epoch [3/50], Step [120/500], Loss: 0.0767
# Epoch [3/50], Step [130/500], Loss: 0.1235
# Epoch [3/50], Step [140/500], Loss: 0.1215
# Epoch [3/50], Step [150/500], Loss: 0.1034
# Epoch [3/50], Step [160/500], Loss: 0.1045
# Epoch [3/50], Step [170/500], Loss: 1.5481
# Epoch [3/50], Step [180/500], Loss: 0.0842
# Epoch [3/50], Step [190/500], Loss: 0.7059
# Epoch [3/50], Step [200/500], Loss: 0.0702
# Epoch [3/50], Step [210/500], Loss: 0.0839
# Epoch [3/50], Step [220/500], Loss: 0.0923
# Epoch [3/50], Step [230/500], Loss: 0.1603
# Epoch [3/50], Step [240/500], Loss: 0.1058
# Epoch [3/50], Step [250/500], Loss: 0.4332
# Epoch [3/50], Step [260/500], Loss: 0.2694
# Epoch [3/50], Step [270/500], Loss: 0.1762
# Epoch [3/50], Step [280/500], Loss: 0.0810
# Epoch [3/50], Step [290/500], Loss: 0.1194
# Epoch [3/50], Step [300/500], Loss: 0.1009
# Epoch [3/50], Step [310/500], Loss: 0.8973
# Epoch [3/50], Step [320/500], Loss: 0.2686
# Epoch [3/50], Step [330/500], Loss: 0.1986
# Epoch [3/50], Step [340/500], Loss: 0.2425
# Epoch [3/50], Step [350/500], Loss: 0.5817
# Epoch [3/50], Step [360/500], Loss: 0.1013
# Epoch [3/50], Step [370/500], Loss: 0.8012
# Epoch [3/50], Step [380/500], Loss: 0.1637
# Epoch [3/50], Step [390/500], Loss: 0.1035
# Epoch [3/50], Step [400/500], Loss: 0.3330
# Epoch [3/50], Step [410/500], Loss: 0.1303
# Epoch [3/50], Step [420/500], Loss: 0.1171
# Epoch [3/50], Step [430/500], Loss: 0.2220
# Epoch [3/50], Step [440/500], Loss: 0.1818
# Epoch [3/50], Step [450/500], Loss: 0.3176
# Epoch [3/50], Step [460/500], Loss: 0.1656
# Epoch [3/50], Step [470/500], Loss: 0.0970
# Epoch [3/50], Step [480/500], Loss: 0.2214
# Epoch [3/50], Step [490/500], Loss: 0.0943
# Epoch [3/50], Step [500/500], Loss: 0.0832
# Epoch [4/50], Step [10/500], Loss: 0.1343
# Epoch [4/50], Step [20/500], Loss: 0.0822
# Epoch [4/50], Step [30/500], Loss: 1.1731
# Epoch [4/50], Step [40/500], Loss: 0.3645
# Epoch [4/50], Step [50/500], Loss: 0.2253
# Epoch [4/50], Step [60/500], Loss: 0.0852
# Epoch [4/50], Step [70/500], Loss: 0.0837
# Epoch [4/50], Step [80/500], Loss: 0.4543
# Epoch [4/50], Step [90/500], Loss: 0.0914
# Epoch [4/50], Step [100/500], Loss: 0.0732
# Epoch [4/50], Step [110/500], Loss: 0.5675
# Epoch [4/50], Step [120/500], Loss: 0.0825
# Epoch [4/50], Step [130/500], Loss: 0.1766
# Epoch [4/50], Step [140/500], Loss: 0.2306
# Epoch [4/50], Step [150/500], Loss: 0.7474
# Epoch [4/50], Step [160/500], Loss: 0.2016
# Epoch [4/50], Step [170/500], Loss: 0.0867
# Epoch [4/50], Step [180/500], Loss: 0.0838
# Epoch [4/50], Step [190/500], Loss: 0.0752
# Epoch [4/50], Step [200/500], Loss: 0.7560
# Epoch [4/50], Step [210/500], Loss: 0.4006
# Epoch [4/50], Step [220/500], Loss: 0.8188
# Epoch [4/50], Step [230/500], Loss: 0.5975
# Epoch [4/50], Step [240/500], Loss: 0.1046
# Epoch [4/50], Step [250/500], Loss: 0.1527
# Epoch [4/50], Step [260/500], Loss: 0.0990
# Epoch [4/50], Step [270/500], Loss: 0.7511
# Epoch [4/50], Step [280/500], Loss: 0.0919
# Epoch [4/50], Step [290/500], Loss: 0.1714
# Epoch [4/50], Step [300/500], Loss: 0.0967
# Epoch [4/50], Step [310/500], Loss: 0.8186
# Epoch [4/50], Step [320/500], Loss: 0.4083
# Epoch [4/50], Step [330/500], Loss: 0.2908
# Epoch [4/50], Step [340/500], Loss: 0.1141
# Epoch [4/50], Step [350/500], Loss: 0.5602
# Epoch [4/50], Step [360/500], Loss: 0.0664
# Epoch [4/50], Step [370/500], Loss: 0.4413
# Epoch [4/50], Step [380/500], Loss: 0.1195
# Epoch [4/50], Step [390/500], Loss: 0.1119
# Epoch [4/50], Step [400/500], Loss: 0.0981
# Epoch [4/50], Step [410/500], Loss: 0.0857
# Epoch [4/50], Step [420/500], Loss: 0.0825
# Epoch [4/50], Step [430/500], Loss: 0.0697
# Epoch [4/50], Step [440/500], Loss: 0.1118
# Epoch [4/50], Step [450/500], Loss: 0.0644
# Epoch [4/50], Step [460/500], Loss: 0.1021
# Epoch [4/50], Step [470/500], Loss: 0.2290
# Epoch [4/50], Step [480/500], Loss: 0.2650
# Epoch [4/50], Step [490/500], Loss: 0.4244
# Epoch [4/50], Step [500/500], Loss: 0.0830
# Epoch [5/50], Step [10/500], Loss: 0.1910
# Epoch [5/50], Step [20/500], Loss: 0.0968
# Epoch [5/50], Step [30/500], Loss: 0.5837
# Epoch [5/50], Step [40/500], Loss: 0.0936
# Epoch [5/50], Step [50/500], Loss: 0.0656
# Epoch [5/50], Step [60/500], Loss: 0.5152
# Epoch [5/50], Step [70/500], Loss: 0.0926
# Epoch [5/50], Step [80/500], Loss: 0.4484
# Epoch [5/50], Step [90/500], Loss: 0.3516
# Epoch [5/50], Step [100/500], Loss: 0.2530
# Epoch [5/50], Step [110/500], Loss: 0.3556
# Epoch [5/50], Step [120/500], Loss: 0.0744
# Epoch [5/50], Step [130/500], Loss: 0.2218
# Epoch [5/50], Step [140/500], Loss: 0.0716
# Epoch [5/50], Step [150/500], Loss: 0.8971
# Epoch [5/50], Step [160/500], Loss: 0.1430
# Epoch [5/50], Step [170/500], Loss: 0.2297
# Epoch [5/50], Step [180/500], Loss: 0.0838
# Epoch [5/50], Step [190/500], Loss: 1.5229
# Epoch [5/50], Step [200/500], Loss: 0.4228
# Epoch [5/50], Step [210/500], Loss: 0.3211
# Epoch [5/50], Step [220/500], Loss: 0.4283
# Epoch [5/50], Step [230/500], Loss: 0.0793
# Epoch [5/50], Step [240/500], Loss: 0.2837
# Epoch [5/50], Step [250/500], Loss: 0.7186
# Epoch [5/50], Step [260/500], Loss: 0.4239
# Epoch [5/50], Step [270/500], Loss: 0.5654
# Epoch [5/50], Step [280/500], Loss: 0.4908
# Epoch [5/50], Step [290/500], Loss: 0.0794
# Epoch [5/50], Step [300/500], Loss: 0.1883
# Epoch [5/50], Step [310/500], Loss: 0.0985
# Epoch [5/50], Step [320/500], Loss: 0.5669
# Epoch [5/50], Step [330/500], Loss: 0.3741
# Epoch [5/50], Step [340/500], Loss: 0.4717
# Epoch [5/50], Step [350/500], Loss: 0.1219
# Epoch [5/50], Step [360/500], Loss: 0.0823
# Epoch [5/50], Step [370/500], Loss: 0.4908
# Epoch [5/50], Step [380/500], Loss: 0.5740
# Epoch [5/50], Step [390/500], Loss: 0.0970
# Epoch [5/50], Step [400/500], Loss: 0.3671
# Epoch [5/50], Step [410/500], Loss: 0.0945
# Epoch [5/50], Step [420/500], Loss: 0.0791
# Epoch [5/50], Step [430/500], Loss: 0.3438
# Epoch [5/50], Step [440/500], Loss: 0.8348
# Epoch [5/50], Step [450/500], Loss: 0.1132
# Epoch [5/50], Step [460/500], Loss: 0.6481
# Epoch [5/50], Step [470/500], Loss: 0.2406
# Epoch [5/50], Step [480/500], Loss: 0.8123
# Epoch [5/50], Step [490/500], Loss: 0.2577
# Epoch [5/50], Step [500/500], Loss: 0.9702
# Epoch [6/50], Step [10/500], Loss: 0.0979
# Epoch [6/50], Step [20/500], Loss: 0.0842
# Epoch [6/50], Step [30/500], Loss: 0.0745
# Epoch [6/50], Step [40/500], Loss: 0.3714
# Epoch [6/50], Step [50/500], Loss: 0.1078
# Epoch [6/50], Step [60/500], Loss: 0.0830
# Epoch [6/50], Step [70/500], Loss: 0.2979
# Epoch [6/50], Step [80/500], Loss: 0.1132
# Epoch [6/50], Step [90/500], Loss: 0.0758
# Epoch [6/50], Step [100/500], Loss: 0.5246
# Epoch [6/50], Step [110/500], Loss: 0.1372
# Epoch [6/50], Step [120/500], Loss: 0.4871
# Epoch [6/50], Step [130/500], Loss: 0.1153
# Epoch [6/50], Step [140/500], Loss: 0.0900
# Epoch [6/50], Step [150/500], Loss: 0.0828
# Epoch [6/50], Step [160/500], Loss: 0.1232
# Epoch [6/50], Step [170/500], Loss: 0.3115
# Epoch [6/50], Step [180/500], Loss: 0.4159
# Epoch [6/50], Step [190/500], Loss: 0.7895
# Epoch [6/50], Step [200/500], Loss: 0.1859
# Epoch [6/50], Step [210/500], Loss: 0.0909
# Epoch [6/50], Step [220/500], Loss: 0.0838
# Epoch [6/50], Step [230/500], Loss: 0.1288
# Epoch [6/50], Step [240/500], Loss: 0.1641
# Epoch [6/50], Step [250/500], Loss: 0.5806
# Epoch [6/50], Step [260/500], Loss: 0.3841
# Epoch [6/50], Step [270/500], Loss: 0.1332
# Epoch [6/50], Step [280/500], Loss: 0.4690
# Epoch [6/50], Step [290/500], Loss: 0.0952
# Epoch [6/50], Step [300/500], Loss: 0.6731
# Epoch [6/50], Step [310/500], Loss: 0.4797
# Epoch [6/50], Step [320/500], Loss: 0.1068
# Epoch [6/50], Step [330/500], Loss: 0.2238
# Epoch [6/50], Step [340/500], Loss: 0.1095
# Epoch [6/50], Step [350/500], Loss: 0.1099
# Epoch [6/50], Step [360/500], Loss: 0.0818
# Epoch [6/50], Step [370/500], Loss: 0.1253
# Epoch [6/50], Step [380/500], Loss: 0.1056
# Epoch [6/50], Step [390/500], Loss: 0.5811
# Epoch [6/50], Step [400/500], Loss: 0.1014
# Epoch [6/50], Step [410/500], Loss: 0.1308
# Epoch [6/50], Step [420/500], Loss: 0.1494
# Epoch [6/50], Step [430/500], Loss: 0.0774
# Epoch [6/50], Step [440/500], Loss: 0.3781
# Epoch [6/50], Step [450/500], Loss: 0.2489
# Epoch [6/50], Step [460/500], Loss: 0.1861
# Epoch [6/50], Step [470/500], Loss: 0.1184
# Epoch [6/50], Step [480/500], Loss: 0.4899
# Epoch [6/50], Step [490/500], Loss: 0.4655
# Epoch [6/50], Step [500/500], Loss: 0.4004
# Epoch [7/50], Step [10/500], Loss: 0.0825
# Epoch [7/50], Step [20/500], Loss: 0.1267
# Epoch [7/50], Step [30/500], Loss: 0.0932
# Epoch [7/50], Step [40/500], Loss: 0.0785
# Epoch [7/50], Step [50/500], Loss: 0.0960
# Epoch [7/50], Step [60/500], Loss: 0.1042
# Epoch [7/50], Step [70/500], Loss: 0.4451
# Epoch [7/50], Step [80/500], Loss: 0.1079
# Epoch [7/50], Step [90/500], Loss: 0.1046
# Epoch [7/50], Step [100/500], Loss: 0.0861
# Epoch [7/50], Step [110/500], Loss: 0.1092
# Epoch [7/50], Step [120/500], Loss: 0.1508
# Epoch [7/50], Step [130/500], Loss: 0.1355
# Epoch [7/50], Step [140/500], Loss: 0.4278
# Epoch [7/50], Step [150/500], Loss: 0.1092
# Epoch [7/50], Step [160/500], Loss: 0.0809
# Epoch [7/50], Step [170/500], Loss: 0.2508
# Epoch [7/50], Step [180/500], Loss: 0.1354
# Epoch [7/50], Step [190/500], Loss: 0.2698
# Epoch [7/50], Step [200/500], Loss: 0.1340
# Epoch [7/50], Step [210/500], Loss: 0.2534
# Epoch [7/50], Step [220/500], Loss: 0.0946
# Epoch [7/50], Step [230/500], Loss: 0.7668
# Epoch [7/50], Step [240/500], Loss: 0.4520
# Epoch [7/50], Step [250/500], Loss: 0.1608
# Epoch [7/50], Step [260/500], Loss: 0.0878
# Epoch [7/50], Step [270/500], Loss: 0.4074
# Epoch [7/50], Step [280/500], Loss: 0.1107
# Epoch [7/50], Step [290/500], Loss: 0.0902
# Epoch [7/50], Step [300/500], Loss: 0.0931
# Epoch [7/50], Step [310/500], Loss: 0.0799
# Epoch [7/50], Step [320/500], Loss: 0.0698
# Epoch [7/50], Step [330/500], Loss: 0.0863
# Epoch [7/50], Step [340/500], Loss: 0.4214
# Epoch [7/50], Step [350/500], Loss: 0.0986
# Epoch [7/50], Step [360/500], Loss: 0.0971
# Epoch [7/50], Step [370/500], Loss: 0.0985
# Epoch [7/50], Step [380/500], Loss: 0.1192
# Epoch [7/50], Step [390/500], Loss: 0.1192
# Epoch [7/50], Step [400/500], Loss: 0.6060
# Epoch [7/50], Step [410/500], Loss: 0.1058
# Epoch [7/50], Step [420/500], Loss: 0.0821
# Epoch [7/50], Step [430/500], Loss: 0.0804
# Epoch [7/50], Step [440/500], Loss: 0.2499
# Epoch [7/50], Step [450/500], Loss: 0.2114
# Epoch [7/50], Step [460/500], Loss: 0.3130
# Epoch [7/50], Step [470/500], Loss: 0.4514
# Epoch [7/50], Step [480/500], Loss: 0.5379
# Epoch [7/50], Step [490/500], Loss: 0.0853
# Epoch [7/50], Step [500/500], Loss: 0.1308
# Epoch [8/50], Step [10/500], Loss: 0.3092
# Epoch [8/50], Step [20/500], Loss: 0.1155
# Epoch [8/50], Step [30/500], Loss: 0.9898
# Epoch [8/50], Step [40/500], Loss: 0.4440
# Epoch [8/50], Step [50/500], Loss: 0.9203
# Epoch [8/50], Step [60/500], Loss: 0.1618
# Epoch [8/50], Step [70/500], Loss: 0.0861
# Epoch [8/50], Step [80/500], Loss: 0.2969
# Epoch [8/50], Step [90/500], Loss: 0.6551
# Epoch [8/50], Step [100/500], Loss: 0.1080
# Epoch [8/50], Step [110/500], Loss: 0.0878
# Epoch [8/50], Step [120/500], Loss: 0.0823
# Epoch [8/50], Step [130/500], Loss: 0.1312
# Epoch [8/50], Step [140/500], Loss: 0.5343
# Epoch [8/50], Step [150/500], Loss: 0.0937
# Epoch [8/50], Step [160/500], Loss: 0.0863
# Epoch [8/50], Step [170/500], Loss: 0.1570
# Epoch [8/50], Step [180/500], Loss: 0.1134
# Epoch [8/50], Step [190/500], Loss: 0.3863
# Epoch [8/50], Step [200/500], Loss: 0.1470
# Epoch [8/50], Step [210/500], Loss: 0.2112
# Epoch [8/50], Step [220/500], Loss: 0.4351
# Epoch [8/50], Step [230/500], Loss: 0.3654
# Epoch [8/50], Step [240/500], Loss: 0.1038
# Epoch [8/50], Step [250/500], Loss: 0.5346
# Epoch [8/50], Step [260/500], Loss: 0.1057
# Epoch [8/50], Step [270/500], Loss: 0.1940
# Epoch [8/50], Step [280/500], Loss: 0.2224
# Epoch [8/50], Step [290/500], Loss: 0.0585
# Epoch [8/50], Step [300/500], Loss: 0.1434
# Epoch [8/50], Step [310/500], Loss: 0.0981
# Epoch [8/50], Step [320/500], Loss: 0.5648
# Epoch [8/50], Step [330/500], Loss: 0.2320
# Epoch [8/50], Step [340/500], Loss: 0.0936
# Epoch [8/50], Step [350/500], Loss: 0.1474
# Epoch [8/50], Step [360/500], Loss: 0.2434
# Epoch [8/50], Step [370/500], Loss: 0.0897
# Epoch [8/50], Step [380/500], Loss: 0.2495
# Epoch [8/50], Step [390/500], Loss: 0.0774
# Epoch [8/50], Step [400/500], Loss: 0.5121
# Epoch [8/50], Step [410/500], Loss: 0.0752
# Epoch [8/50], Step [420/500], Loss: 0.1006
# Epoch [8/50], Step [430/500], Loss: 0.0989
# Epoch [8/50], Step [440/500], Loss: 0.1042
# Epoch [8/50], Step [450/500], Loss: 0.1141
# Epoch [8/50], Step [460/500], Loss: 0.1167
# Epoch [8/50], Step [470/500], Loss: 0.1230
# Epoch [8/50], Step [480/500], Loss: 0.5933
# Epoch [8/50], Step [490/500], Loss: 0.0762
# Epoch [8/50], Step [500/500], Loss: 0.0816
# Epoch [9/50], Step [10/500], Loss: 0.1136
# Epoch [9/50], Step [20/500], Loss: 0.1072
# Epoch [9/50], Step [30/500], Loss: 0.0775
# Epoch [9/50], Step [40/500], Loss: 0.0873
# Epoch [9/50], Step [50/500], Loss: 0.0982
# Epoch [9/50], Step [60/500], Loss: 0.5000
# Epoch [9/50], Step [70/500], Loss: 0.3448
# Epoch [9/50], Step [80/500], Loss: 0.0919
# Epoch [9/50], Step [90/500], Loss: 0.0558
# Epoch [9/50], Step [100/500], Loss: 0.0572
# Epoch [9/50], Step [110/500], Loss: 0.4615
# Epoch [9/50], Step [120/500], Loss: 0.0968
# Epoch [9/50], Step [130/500], Loss: 0.2800
# Epoch [9/50], Step [140/500], Loss: 0.2373
# Epoch [9/50], Step [150/500], Loss: 0.5608
# Epoch [9/50], Step [160/500], Loss: 0.0938
# Epoch [9/50], Step [170/500], Loss: 0.3717
# Epoch [9/50], Step [180/500], Loss: 0.4765
# Epoch [9/50], Step [190/500], Loss: 0.0823
# Epoch [9/50], Step [200/500], Loss: 0.0803
# Epoch [9/50], Step [210/500], Loss: 0.0802
# Epoch [9/50], Step [220/500], Loss: 0.0951
# Epoch [9/50], Step [230/500], Loss: 0.3126
# Epoch [9/50], Step [240/500], Loss: 0.2065
# Epoch [9/50], Step [250/500], Loss: 0.1989
# Epoch [9/50], Step [260/500], Loss: 0.3750
# Epoch [9/50], Step [270/500], Loss: 0.1189
# Epoch [9/50], Step [280/500], Loss: 0.6788
# Epoch [9/50], Step [290/500], Loss: 0.5329
# Epoch [9/50], Step [300/500], Loss: 0.2656
# Epoch [9/50], Step [310/500], Loss: 0.5458
# Epoch [9/50], Step [320/500], Loss: 0.2151
# Epoch [9/50], Step [330/500], Loss: 0.0866
# Epoch [9/50], Step [340/500], Loss: 0.4720
# Epoch [9/50], Step [350/500], Loss: 0.3124
# Epoch [9/50], Step [360/500], Loss: 0.0899
# Epoch [9/50], Step [370/500], Loss: 0.0974
# Epoch [9/50], Step [380/500], Loss: 0.0938
# Epoch [9/50], Step [390/500], Loss: 0.7073
# Epoch [9/50], Step [400/500], Loss: 0.1112
# Epoch [9/50], Step [410/500], Loss: 0.0590
# Epoch [9/50], Step [420/500], Loss: 0.1841
# Epoch [9/50], Step [430/500], Loss: 0.4584
# Epoch [9/50], Step [440/500], Loss: 0.5824
# Epoch [9/50], Step [450/500], Loss: 0.4735
# Epoch [9/50], Step [460/500], Loss: 0.0766
# Epoch [9/50], Step [470/500], Loss: 0.0771
# Epoch [9/50], Step [480/500], Loss: 0.0807
# Epoch [9/50], Step [490/500], Loss: 0.0992
# Epoch [9/50], Step [500/500], Loss: 0.0737
# Epoch [10/50], Step [10/500], Loss: 0.0688
# Epoch [10/50], Step [20/500], Loss: 0.6394
# Epoch [10/50], Step [30/500], Loss: 0.0638
# Epoch [10/50], Step [40/500], Loss: 0.7408
# Epoch [10/50], Step [50/500], Loss: 0.1003
# Epoch [10/50], Step [60/500], Loss: 0.0848
# Epoch [10/50], Step [70/500], Loss: 0.1864
# Epoch [10/50], Step [80/500], Loss: 0.0683
# Epoch [10/50], Step [90/500], Loss: 0.0690
# Epoch [10/50], Step [100/500], Loss: 0.1042
# Epoch [10/50], Step [110/500], Loss: 0.1224
# Epoch [10/50], Step [120/500], Loss: 0.4641
# Epoch [10/50], Step [130/500], Loss: 0.0691
# Epoch [10/50], Step [140/500], Loss: 0.1058
# Epoch [10/50], Step [150/500], Loss: 0.1140
# Epoch [10/50], Step [160/500], Loss: 0.4029
# Epoch [10/50], Step [170/500], Loss: 0.0866
# Epoch [10/50], Step [180/500], Loss: 0.1108
# Epoch [10/50], Step [190/500], Loss: 0.0727
# Epoch [10/50], Step [200/500], Loss: 0.0878
# Epoch [10/50], Step [210/500], Loss: 0.3800
# Epoch [10/50], Step [220/500], Loss: 0.4824
# Epoch [10/50], Step [230/500], Loss: 0.5195
# Epoch [10/50], Step [240/500], Loss: 0.0721
# Epoch [10/50], Step [250/500], Loss: 0.4627
# Epoch [10/50], Step [260/500], Loss: 0.0982
# Epoch [10/50], Step [270/500], Loss: 0.0900
# Epoch [10/50], Step [280/500], Loss: 0.0701
# Epoch [10/50], Step [290/500], Loss: 0.0833
# Epoch [10/50], Step [300/500], Loss: 0.0975
# Epoch [10/50], Step [310/500], Loss: 0.0785
# Epoch [10/50], Step [320/500], Loss: 0.2879
# Epoch [10/50], Step [330/500], Loss: 0.4116
# Epoch [10/50], Step [340/500], Loss: 0.6207
# Epoch [10/50], Step [350/500], Loss: 0.1044
# Epoch [10/50], Step [360/500], Loss: 0.5124
# Epoch [10/50], Step [370/500], Loss: 0.0927
# Epoch [10/50], Step [380/500], Loss: 0.0741
# Epoch [10/50], Step [390/500], Loss: 0.2963
# Epoch [10/50], Step [400/500], Loss: 0.4548
# Epoch [10/50], Step [410/500], Loss: 0.5336
# Epoch [10/50], Step [420/500], Loss: 0.0944
# Epoch [10/50], Step [430/500], Loss: 0.6110
# Epoch [10/50], Step [440/500], Loss: 0.0783
# Epoch [10/50], Step [450/500], Loss: 0.1279
# Epoch [10/50], Step [460/500], Loss: 0.4806
# Epoch [10/50], Step [470/500], Loss: 0.1029
# Epoch [10/50], Step [480/500], Loss: 0.0655
# Epoch [10/50], Step [490/500], Loss: 0.1042
# Epoch [10/50], Step [500/500], Loss: 0.2825
# Epoch [11/50], Step [10/500], Loss: 0.0897
# Epoch [11/50], Step [20/500], Loss: 0.3717
# Epoch [11/50], Step [30/500], Loss: 0.1070
# Epoch [11/50], Step [40/500], Loss: 0.2456
# Epoch [11/50], Step [50/500], Loss: 0.1125
# Epoch [11/50], Step [60/500], Loss: 0.2762
# Epoch [11/50], Step [70/500], Loss: 0.5498
# Epoch [11/50], Step [80/500], Loss: 0.1741
# Epoch [11/50], Step [90/500], Loss: 0.6220
# Epoch [11/50], Step [100/500], Loss: 0.1051
# Epoch [11/50], Step [110/500], Loss: 0.1083
# Epoch [11/50], Step [120/500], Loss: 0.0927
# Epoch [11/50], Step [130/500], Loss: 0.6014
# Epoch [11/50], Step [140/500], Loss: 0.0896
# Epoch [11/50], Step [150/500], Loss: 0.0962
# Epoch [11/50], Step [160/500], Loss: 0.0878
# Epoch [11/50], Step [170/500], Loss: 0.0776
# Epoch [11/50], Step [180/500], Loss: 0.1082
# Epoch [11/50], Step [190/500], Loss: 0.3088
# Epoch [11/50], Step [200/500], Loss: 0.0975
# Epoch [11/50], Step [210/500], Loss: 0.0971
# Epoch [11/50], Step [220/500], Loss: 0.0976
# Epoch [11/50], Step [230/500], Loss: 0.3719
# Epoch [11/50], Step [240/500], Loss: 0.4220
# Epoch [11/50], Step [250/500], Loss: 0.0769
# Epoch [11/50], Step [260/500], Loss: 0.0766
# Epoch [11/50], Step [270/500], Loss: 0.2900
# Epoch [11/50], Step [280/500], Loss: 0.6079
# Epoch [11/50], Step [290/500], Loss: 0.1054
# Epoch [11/50], Step [300/500], Loss: 0.0993
# Epoch [11/50], Step [310/500], Loss: 0.0845
# Epoch [11/50], Step [320/500], Loss: 0.1147
# Epoch [11/50], Step [330/500], Loss: 0.1194
# Epoch [11/50], Step [340/500], Loss: 0.2148
# Epoch [11/50], Step [350/500], Loss: 0.1114
# Epoch [11/50], Step [360/500], Loss: 0.1785
# Epoch [11/50], Step [370/500], Loss: 0.0895
# Epoch [11/50], Step [380/500], Loss: 0.0696
# Epoch [11/50], Step [390/500], Loss: 0.0715
# Epoch [11/50], Step [400/500], Loss: 0.5185
# Epoch [11/50], Step [410/500], Loss: 0.1870
# Epoch [11/50], Step [420/500], Loss: 0.1211
# Epoch [11/50], Step [430/500], Loss: 0.1574
# Epoch [11/50], Step [440/500], Loss: 0.8066
# Epoch [11/50], Step [450/500], Loss: 0.0848
# Epoch [11/50], Step [460/500], Loss: 0.7257
# Epoch [11/50], Step [470/500], Loss: 0.0735
# Epoch [11/50], Step [480/500], Loss: 0.2557
# Epoch [11/50], Step [490/500], Loss: 0.1825
# Epoch [11/50], Step [500/500], Loss: 0.0896
# Epoch [12/50], Step [10/500], Loss: 0.3219
# Epoch [12/50], Step [20/500], Loss: 0.1048
# Epoch [12/50], Step [30/500], Loss: 0.2118
# Epoch [12/50], Step [40/500], Loss: 0.0788
# Epoch [12/50], Step [50/500], Loss: 0.6304
# Epoch [12/50], Step [60/500], Loss: 0.8570
# Epoch [12/50], Step [70/500], Loss: 0.1147
# Epoch [12/50], Step [80/500], Loss: 0.4821
# Epoch [12/50], Step [90/500], Loss: 0.5026
# Epoch [12/50], Step [100/500], Loss: 0.2512
# Epoch [12/50], Step [110/500], Loss: 0.0823
# Epoch [12/50], Step [120/500], Loss: 0.1282
# Epoch [12/50], Step [130/500], Loss: 0.4929
# Epoch [12/50], Step [140/500], Loss: 0.0993
# Epoch [12/50], Step [150/500], Loss: 0.1156
# Epoch [12/50], Step [160/500], Loss: 0.0825
# Epoch [12/50], Step [170/500], Loss: 0.1016
# Epoch [12/50], Step [180/500], Loss: 0.2598
# Epoch [12/50], Step [190/500], Loss: 0.2326
# Epoch [12/50], Step [200/500], Loss: 0.1073
# Epoch [12/50], Step [210/500], Loss: 0.9791
# Epoch [12/50], Step [220/500], Loss: 0.5327
# Epoch [12/50], Step [230/500], Loss: 0.1099
# Epoch [12/50], Step [240/500], Loss: 0.0946
# Epoch [12/50], Step [250/500], Loss: 0.1014
# Epoch [12/50], Step [260/500], Loss: 0.5142
# Epoch [12/50], Step [270/500], Loss: 0.1027
# Epoch [12/50], Step [280/500], Loss: 0.0641
# Epoch [12/50], Step [290/500], Loss: 0.1613
# Epoch [12/50], Step [300/500], Loss: 0.6114
# Epoch [12/50], Step [310/500], Loss: 0.0716
# Epoch [12/50], Step [320/500], Loss: 0.3658
# Epoch [12/50], Step [330/500], Loss: 0.0871
# Epoch [12/50], Step [340/500], Loss: 0.0690
# Epoch [12/50], Step [350/500], Loss: 0.1355
# Epoch [12/50], Step [360/500], Loss: 0.5950
# Epoch [12/50], Step [370/500], Loss: 0.2919
# Epoch [12/50], Step [380/500], Loss: 0.0618
# Epoch [12/50], Step [390/500], Loss: 0.5350
# Epoch [12/50], Step [400/500], Loss: 0.0820
# Epoch [12/50], Step [410/500], Loss: 0.1622
# Epoch [12/50], Step [420/500], Loss: 0.2963
# Epoch [12/50], Step [430/500], Loss: 0.1407
# Epoch [12/50], Step [440/500], Loss: 0.4838
# Epoch [12/50], Step [450/500], Loss: 0.1253
# Epoch [12/50], Step [460/500], Loss: 0.2941
# Epoch [12/50], Step [470/500], Loss: 0.0612
# Epoch [12/50], Step [480/500], Loss: 0.6542
# Epoch [12/50], Step [490/500], Loss: 0.2076
# Epoch [12/50], Step [500/500], Loss: 0.4726
# Epoch [13/50], Step [10/500], Loss: 0.0814
# Epoch [13/50], Step [20/500], Loss: 0.0830
# Epoch [13/50], Step [30/500], Loss: 0.2973
# Epoch [13/50], Step [40/500], Loss: 0.0548
# Epoch [13/50], Step [50/500], Loss: 0.1651
# Epoch [13/50], Step [60/500], Loss: 0.0787
# Epoch [13/50], Step [70/500], Loss: 0.1244
# Epoch [13/50], Step [80/500], Loss: 0.0854
# Epoch [13/50], Step [90/500], Loss: 0.3274
# Epoch [13/50], Step [100/500], Loss: 0.0725
# Epoch [13/50], Step [110/500], Loss: 0.0798
# Epoch [13/50], Step [120/500], Loss: 0.1117
# Epoch [13/50], Step [130/500], Loss: 0.5050
# Epoch [13/50], Step [140/500], Loss: 0.5924
# Epoch [13/50], Step [150/500], Loss: 0.1937
# Epoch [13/50], Step [160/500], Loss: 0.2520
# Epoch [13/50], Step [170/500], Loss: 0.1056
# Epoch [13/50], Step [180/500], Loss: 0.1774
# Epoch [13/50], Step [190/500], Loss: 0.1245
# Epoch [13/50], Step [200/500], Loss: 0.5641
# Epoch [13/50], Step [210/500], Loss: 0.0768
# Epoch [13/50], Step [220/500], Loss: 0.2510
# Epoch [13/50], Step [230/500], Loss: 0.7007
# Epoch [13/50], Step [240/500], Loss: 0.4312
# Epoch [13/50], Step [250/500], Loss: 0.3348
# Epoch [13/50], Step [260/500], Loss: 0.1009
# Epoch [13/50], Step [270/500], Loss: 0.0863
# Epoch [13/50], Step [280/500], Loss: 0.1055
# Epoch [13/50], Step [290/500], Loss: 0.1235
# Epoch [13/50], Step [300/500], Loss: 0.2940
# Epoch [13/50], Step [310/500], Loss: 0.1063
# Epoch [13/50], Step [320/500], Loss: 0.1731
# Epoch [13/50], Step [330/500], Loss: 0.0840
# Epoch [13/50], Step [340/500], Loss: 0.3857
# Epoch [13/50], Step [350/500], Loss: 0.6006
# Epoch [13/50], Step [360/500], Loss: 0.3708
# Epoch [13/50], Step [370/500], Loss: 0.1067
# Epoch [13/50], Step [380/500], Loss: 0.0813
# Epoch [13/50], Step [390/500], Loss: 0.1995
# Epoch [13/50], Step [400/500], Loss: 0.0698
# Epoch [13/50], Step [410/500], Loss: 0.6498
# Epoch [13/50], Step [420/500], Loss: 0.1883
# Epoch [13/50], Step [430/500], Loss: 0.0756
# Epoch [13/50], Step [440/500], Loss: 0.4759
# Epoch [13/50], Step [450/500], Loss: 0.5818
# Epoch [13/50], Step [460/500], Loss: 0.1167
# Epoch [13/50], Step [470/500], Loss: 0.2950
# Epoch [13/50], Step [480/500], Loss: 0.0928
# Epoch [13/50], Step [490/500], Loss: 0.0872
# Epoch [13/50], Step [500/500], Loss: 0.1747
# Epoch [14/50], Step [10/500], Loss: 0.3024
# Epoch [14/50], Step [20/500], Loss: 0.0877
# Epoch [14/50], Step [30/500], Loss: 0.2956
# Epoch [14/50], Step [40/500], Loss: 0.1049
# Epoch [14/50], Step [50/500], Loss: 0.1100
# Epoch [14/50], Step [60/500], Loss: 0.1341
# Epoch [14/50], Step [70/500], Loss: 0.5197
# Epoch [14/50], Step [80/500], Loss: 0.1393
# Epoch [14/50], Step [90/500], Loss: 0.4495
# Epoch [14/50], Step [100/500], Loss: 0.0842
# Epoch [14/50], Step [110/500], Loss: 0.5451
# Epoch [14/50], Step [120/500], Loss: 0.1111
# Epoch [14/50], Step [130/500], Loss: 0.0968
# Epoch [14/50], Step [140/500], Loss: 0.0997
# Epoch [14/50], Step [150/500], Loss: 0.0889
# Epoch [14/50], Step [160/500], Loss: 0.0493
# Epoch [14/50], Step [170/500], Loss: 0.5171
# Epoch [14/50], Step [180/500], Loss: 0.1608
# Epoch [14/50], Step [190/500], Loss: 0.6694
# Epoch [14/50], Step [200/500], Loss: 0.5686
# Epoch [14/50], Step [210/500], Loss: 0.4349
# Epoch [14/50], Step [220/500], Loss: 0.0874
# Epoch [14/50], Step [230/500], Loss: 0.1037
# Epoch [14/50], Step [240/500], Loss: 0.0862
# Epoch [14/50], Step [250/500], Loss: 0.0955
# Epoch [14/50], Step [260/500], Loss: 0.0866
# Epoch [14/50], Step [270/500], Loss: 0.5185
# Epoch [14/50], Step [280/500], Loss: 0.0845
# Epoch [14/50], Step [290/500], Loss: 0.1111
# Epoch [14/50], Step [300/500], Loss: 0.0810
# Epoch [14/50], Step [310/500], Loss: 0.4168
# Epoch [14/50], Step [320/500], Loss: 0.0862
# Epoch [14/50], Step [330/500], Loss: 0.2081
# Epoch [14/50], Step [340/500], Loss: 0.0905
# Epoch [14/50], Step [350/500], Loss: 0.3377
# Epoch [14/50], Step [360/500], Loss: 0.2675
# Epoch [14/50], Step [370/500], Loss: 0.0950
# Epoch [14/50], Step [380/500], Loss: 0.0662
# Epoch [14/50], Step [390/500], Loss: 0.4533
# Epoch [14/50], Step [400/500], Loss: 0.2861
# Epoch [14/50], Step [410/500], Loss: 0.1449
# Epoch [14/50], Step [420/500], Loss: 0.4100
# Epoch [14/50], Step [430/500], Loss: 0.0900
# Epoch [14/50], Step [440/500], Loss: 0.0898
# Epoch [14/50], Step [450/500], Loss: 0.2535
# Epoch [14/50], Step [460/500], Loss: 0.1243
# Epoch [14/50], Step [470/500], Loss: 0.0692
# Epoch [14/50], Step [480/500], Loss: 0.1901
# Epoch [14/50], Step [490/500], Loss: 1.0019
# Epoch [14/50], Step [500/500], Loss: 0.0725
# Epoch [15/50], Step [10/500], Loss: 0.0493
# Epoch [15/50], Step [20/500], Loss: 0.5880
# Epoch [15/50], Step [30/500], Loss: 0.0659
# Epoch [15/50], Step [40/500], Loss: 0.2571
# Epoch [15/50], Step [50/500], Loss: 0.1108
# Epoch [15/50], Step [60/500], Loss: 0.0846
# Epoch [15/50], Step [70/500], Loss: 0.1897
# Epoch [15/50], Step [80/500], Loss: 0.2910
# Epoch [15/50], Step [90/500], Loss: 0.1279
# Epoch [15/50], Step [100/500], Loss: 0.1139
# Epoch [15/50], Step [110/500], Loss: 0.0855
# Epoch [15/50], Step [120/500], Loss: 0.1137
# Epoch [15/50], Step [130/500], Loss: 0.4574
# Epoch [15/50], Step [140/500], Loss: 0.1147
# Epoch [15/50], Step [150/500], Loss: 0.1106
# Epoch [15/50], Step [160/500], Loss: 0.0924
# Epoch [15/50], Step [170/500], Loss: 0.1878
# Epoch [15/50], Step [180/500], Loss: 0.2779
# Epoch [15/50], Step [190/500], Loss: 0.1455
# Epoch [15/50], Step [200/500], Loss: 0.6013
# Epoch [15/50], Step [210/500], Loss: 0.1343
# Epoch [15/50], Step [220/500], Loss: 0.3433
# Epoch [15/50], Step [230/500], Loss: 0.2306
# Epoch [15/50], Step [240/500], Loss: 0.5266
# Epoch [15/50], Step [250/500], Loss: 0.0780
# Epoch [15/50], Step [260/500], Loss: 0.0553
# Epoch [15/50], Step [270/500], Loss: 0.4742
# Epoch [15/50], Step [280/500], Loss: 0.1249
# Epoch [15/50], Step [290/500], Loss: 0.0813
# Epoch [15/50], Step [300/500], Loss: 0.1148
# Epoch [15/50], Step [310/500], Loss: 0.1503
# Epoch [15/50], Step [320/500], Loss: 0.0873
# Epoch [15/50], Step [330/500], Loss: 0.0782
# Epoch [15/50], Step [340/500], Loss: 0.0861
# Epoch [15/50], Step [350/500], Loss: 0.0779
# Epoch [15/50], Step [360/500], Loss: 0.1956
# Epoch [15/50], Step [370/500], Loss: 0.1045
# Epoch [15/50], Step [380/500], Loss: 0.3803
# Epoch [15/50], Step [390/500], Loss: 0.0918
# Epoch [15/50], Step [400/500], Loss: 0.1054
# Epoch [15/50], Step [410/500], Loss: 0.7466
# Epoch [15/50], Step [420/500], Loss: 0.0578
# Epoch [15/50], Step [430/500], Loss: 0.0755
# Epoch [15/50], Step [440/500], Loss: 0.2062
# Epoch [15/50], Step [450/500], Loss: 0.5400
# Epoch [15/50], Step [460/500], Loss: 0.2881
# Epoch [15/50], Step [470/500], Loss: 0.3127
# Epoch [15/50], Step [480/500], Loss: 0.0847
# Epoch [15/50], Step [490/500], Loss: 0.3488
# Epoch [15/50], Step [500/500], Loss: 0.2448
# Epoch [16/50], Step [10/500], Loss: 0.1355
# Epoch [16/50], Step [20/500], Loss: 0.1262
# Epoch [16/50], Step [30/500], Loss: 0.0709
# Epoch [16/50], Step [40/500], Loss: 0.0750
# Epoch [16/50], Step [50/500], Loss: 0.1565
# Epoch [16/50], Step [60/500], Loss: 0.1038
# Epoch [16/50], Step [70/500], Loss: 0.0851
# Epoch [16/50], Step [80/500], Loss: 0.0696
# Epoch [16/50], Step [90/500], Loss: 0.3368
# Epoch [16/50], Step [100/500], Loss: 0.3673
# Epoch [16/50], Step [110/500], Loss: 0.2419
# Epoch [16/50], Step [120/500], Loss: 0.0773
# Epoch [16/50], Step [130/500], Loss: 0.0831
# Epoch [16/50], Step [140/500], Loss: 0.1108
# Epoch [16/50], Step [150/500], Loss: 0.0548
# Epoch [16/50], Step [160/500], Loss: 0.2759
# Epoch [16/50], Step [170/500], Loss: 0.6221
# Epoch [16/50], Step [180/500], Loss: 0.1101
# Epoch [16/50], Step [190/500], Loss: 0.0718
# Epoch [16/50], Step [200/500], Loss: 0.0866
# Epoch [16/50], Step [210/500], Loss: 0.2279
# Epoch [16/50], Step [220/500], Loss: 0.1618
# Epoch [16/50], Step [230/500], Loss: 0.1205
# Epoch [16/50], Step [240/500], Loss: 0.0847
# Epoch [16/50], Step [250/500], Loss: 0.6003
# Epoch [16/50], Step [260/500], Loss: 0.0798
# Epoch [16/50], Step [270/500], Loss: 0.4398
# Epoch [16/50], Step [280/500], Loss: 0.0795
# Epoch [16/50], Step [290/500], Loss: 0.6494
# Epoch [16/50], Step [300/500], Loss: 0.0879
# Epoch [16/50], Step [310/500], Loss: 0.0986
# Epoch [16/50], Step [320/500], Loss: 0.2902
# Epoch [16/50], Step [330/500], Loss: 0.0706
# Epoch [16/50], Step [340/500], Loss: 0.1807
# Epoch [16/50], Step [350/500], Loss: 0.1193
# Epoch [16/50], Step [360/500], Loss: 0.0731
# Epoch [16/50], Step [370/500], Loss: 0.2640
# Epoch [16/50], Step [380/500], Loss: 0.3042
# Epoch [16/50], Step [390/500], Loss: 0.3846
# Epoch [16/50], Step [400/500], Loss: 0.0877
# Epoch [16/50], Step [410/500], Loss: 0.1137
# Epoch [16/50], Step [420/500], Loss: 0.1883
# Epoch [16/50], Step [430/500], Loss: 0.3593
# Epoch [16/50], Step [440/500], Loss: 0.1996
# Epoch [16/50], Step [450/500], Loss: 0.5195
# Epoch [16/50], Step [460/500], Loss: 0.0699
# Epoch [16/50], Step [470/500], Loss: 0.2277
# Epoch [16/50], Step [480/500], Loss: 0.5514
# Epoch [16/50], Step [490/500], Loss: 0.1045
# Epoch [16/50], Step [500/500], Loss: 0.0972
# Epoch [17/50], Step [10/500], Loss: 0.0715
# Epoch [17/50], Step [20/500], Loss: 0.1062
# Epoch [17/50], Step [30/500], Loss: 0.0860
# Epoch [17/50], Step [40/500], Loss: 0.0559
# Epoch [17/50], Step [50/500], Loss: 0.0851
# Epoch [17/50], Step [60/500], Loss: 0.2662
# Epoch [17/50], Step [70/500], Loss: 0.4901
# Epoch [17/50], Step [80/500], Loss: 0.0674
# Epoch [17/50], Step [90/500], Loss: 0.1005
# Epoch [17/50], Step [100/500], Loss: 0.0712
# Epoch [17/50], Step [110/500], Loss: 0.0954
# Epoch [17/50], Step [120/500], Loss: 0.6662
# Epoch [17/50], Step [130/500], Loss: 0.1011
# Epoch [17/50], Step [140/500], Loss: 0.0843
# Epoch [17/50], Step [150/500], Loss: 0.6688
# Epoch [17/50], Step [160/500], Loss: 0.0944
# Epoch [17/50], Step [170/500], Loss: 0.0981
# Epoch [17/50], Step [180/500], Loss: 0.4643
# Epoch [17/50], Step [190/500], Loss: 0.1869
# Epoch [17/50], Step [200/500], Loss: 0.0920
# Epoch [17/50], Step [210/500], Loss: 0.2309
# Epoch [17/50], Step [220/500], Loss: 0.0911
# Epoch [17/50], Step [230/500], Loss: 0.1870
# Epoch [17/50], Step [240/500], Loss: 0.1284
# Epoch [17/50], Step [250/500], Loss: 0.0805
# Epoch [17/50], Step [260/500], Loss: 0.3622
# Epoch [17/50], Step [270/500], Loss: 0.3859
# Epoch [17/50], Step [280/500], Loss: 0.8215
# Epoch [17/50], Step [290/500], Loss: 0.1061
# Epoch [17/50], Step [300/500], Loss: 0.1862
# Epoch [17/50], Step [310/500], Loss: 0.4857
# Epoch [17/50], Step [320/500], Loss: 0.5376
# Epoch [17/50], Step [330/500], Loss: 0.1540
# Epoch [17/50], Step [340/500], Loss: 0.4236
# Epoch [17/50], Step [350/500], Loss: 0.5527
# Epoch [17/50], Step [360/500], Loss: 0.0883
# Epoch [17/50], Step [370/500], Loss: 0.0732
# Epoch [17/50], Step [380/500], Loss: 0.0782
# Epoch [17/50], Step [390/500], Loss: 0.1044
# Epoch [17/50], Step [400/500], Loss: 0.0962
# Epoch [17/50], Step [410/500], Loss: 0.3776
# Epoch [17/50], Step [420/500], Loss: 0.5494
# Epoch [17/50], Step [430/500], Loss: 0.4980
# Epoch [17/50], Step [440/500], Loss: 0.0896
# Epoch [17/50], Step [450/500], Loss: 0.0729
# Epoch [17/50], Step [460/500], Loss: 0.1158
# Epoch [17/50], Step [470/500], Loss: 0.5724
# Epoch [17/50], Step [480/500], Loss: 0.0938
# Epoch [17/50], Step [490/500], Loss: 0.0860
# Epoch [17/50], Step [500/500], Loss: 0.1608
# Epoch [18/50], Step [10/500], Loss: 0.8370
# Epoch [18/50], Step [20/500], Loss: 0.0730
# Epoch [18/50], Step [30/500], Loss: 0.4677
# Epoch [18/50], Step [40/500], Loss: 0.0921
# Epoch [18/50], Step [50/500], Loss: 0.9195
# Epoch [18/50], Step [60/500], Loss: 0.0978
# Epoch [18/50], Step [70/500], Loss: 0.0756
# Epoch [18/50], Step [80/500], Loss: 0.1709
# Epoch [18/50], Step [90/500], Loss: 0.4966
# Epoch [18/50], Step [100/500], Loss: 0.2131
# Epoch [18/50], Step [110/500], Loss: 0.3558
# Epoch [18/50], Step [120/500], Loss: 0.0729
# Epoch [18/50], Step [130/500], Loss: 0.1003
# Epoch [18/50], Step [140/500], Loss: 0.2312
# Epoch [18/50], Step [150/500], Loss: 0.3472
# Epoch [18/50], Step [160/500], Loss: 0.4769
# Epoch [18/50], Step [170/500], Loss: 0.3299
# Epoch [18/50], Step [180/500], Loss: 0.0942
# Epoch [18/50], Step [190/500], Loss: 0.1382
# Epoch [18/50], Step [200/500], Loss: 0.3297
# Epoch [18/50], Step [210/500], Loss: 0.8820
# Epoch [18/50], Step [220/500], Loss: 0.0889
# Epoch [18/50], Step [230/500], Loss: 0.2494
# Epoch [18/50], Step [240/500], Loss: 0.0817
# Epoch [18/50], Step [250/500], Loss: 0.0937
# Epoch [18/50], Step [260/500], Loss: 0.2974
# Epoch [18/50], Step [270/500], Loss: 0.1055
# Epoch [18/50], Step [280/500], Loss: 0.4490
# Epoch [18/50], Step [290/500], Loss: 0.1510
# Epoch [18/50], Step [300/500], Loss: 0.7303
# Epoch [18/50], Step [310/500], Loss: 0.2831
# Epoch [18/50], Step [320/500], Loss: 0.0957
# Epoch [18/50], Step [330/500], Loss: 0.1166
# Epoch [18/50], Step [340/500], Loss: 0.2685
# Epoch [18/50], Step [350/500], Loss: 0.0996
# Epoch [18/50], Step [360/500], Loss: 0.0718
# Epoch [18/50], Step [370/500], Loss: 0.0950
# Epoch [18/50], Step [380/500], Loss: 0.7243
# Epoch [18/50], Step [390/500], Loss: 1.0866
# Epoch [18/50], Step [400/500], Loss: 0.1118
# Epoch [18/50], Step [410/500], Loss: 0.4487
# Epoch [18/50], Step [420/500], Loss: 0.0991
# Epoch [18/50], Step [430/500], Loss: 0.1512
# Epoch [18/50], Step [440/500], Loss: 0.1981
# Epoch [18/50], Step [450/500], Loss: 0.0848
# Epoch [18/50], Step [460/500], Loss: 0.0680
# Epoch [18/50], Step [470/500], Loss: 0.0876
# Epoch [18/50], Step [480/500], Loss: 0.1545
# Epoch [18/50], Step [490/500], Loss: 0.1792
# Epoch [18/50], Step [500/500], Loss: 0.5220
# Epoch [19/50], Step [10/500], Loss: 0.0715
# Epoch [19/50], Step [20/500], Loss: 0.0902
# Epoch [19/50], Step [30/500], Loss: 0.1486
# Epoch [19/50], Step [40/500], Loss: 0.0836
# Epoch [19/50], Step [50/500], Loss: 0.5996
# Epoch [19/50], Step [60/500], Loss: 0.2983
# Epoch [19/50], Step [70/500], Loss: 0.0930
# Epoch [19/50], Step [80/500], Loss: 0.0620
# Epoch [19/50], Step [90/500], Loss: 0.1112
# Epoch [19/50], Step [100/500], Loss: 0.5856
# Epoch [19/50], Step [110/500], Loss: 0.1125
# Epoch [19/50], Step [120/500], Loss: 0.2876
# Epoch [19/50], Step [130/500], Loss: 0.1037
# Epoch [19/50], Step [140/500], Loss: 0.0832
# Epoch [19/50], Step [150/500], Loss: 0.1208
# Epoch [19/50], Step [160/500], Loss: 0.3802
# Epoch [19/50], Step [170/500], Loss: 0.0851
# Epoch [19/50], Step [180/500], Loss: 0.0911
# Epoch [19/50], Step [190/500], Loss: 0.4777
# Epoch [19/50], Step [200/500], Loss: 0.0991
# Epoch [19/50], Step [210/500], Loss: 0.0894
# Epoch [19/50], Step [220/500], Loss: 0.2623
# Epoch [19/50], Step [230/500], Loss: 0.2514
# Epoch [19/50], Step [240/500], Loss: 0.0798
# Epoch [19/50], Step [250/500], Loss: 0.0860
# Epoch [19/50], Step [260/500], Loss: 0.2927
# Epoch [19/50], Step [270/500], Loss: 0.2090
# Epoch [19/50], Step [280/500], Loss: 0.4855
# Epoch [19/50], Step [290/500], Loss: 0.1455
# Epoch [19/50], Step [300/500], Loss: 0.1073
# Epoch [19/50], Step [310/500], Loss: 0.2096
# Epoch [19/50], Step [320/500], Loss: 0.0717
# Epoch [19/50], Step [330/500], Loss: 0.1117
# Epoch [19/50], Step [340/500], Loss: 0.2721
# Epoch [19/50], Step [350/500], Loss: 0.2462
# Epoch [19/50], Step [360/500], Loss: 0.1108
# Epoch [19/50], Step [370/500], Loss: 0.1395
# Epoch [19/50], Step [380/500], Loss: 0.0803
# Epoch [19/50], Step [390/500], Loss: 0.0832
# Epoch [19/50], Step [400/500], Loss: 0.1497
# Epoch [19/50], Step [410/500], Loss: 0.0678
# Epoch [19/50], Step [420/500], Loss: 0.0843
# Epoch [19/50], Step [430/500], Loss: 0.2875
# Epoch [19/50], Step [440/500], Loss: 0.1886
# Epoch [19/50], Step [450/500], Loss: 0.0922
# Epoch [19/50], Step [460/500], Loss: 0.1268
# Epoch [19/50], Step [470/500], Loss: 0.1490
# Epoch [19/50], Step [480/500], Loss: 0.0819
# Epoch [19/50], Step [490/500], Loss: 0.0642
# Epoch [19/50], Step [500/500], Loss: 0.1063
# Epoch [20/50], Step [10/500], Loss: 0.2299
# Epoch [20/50], Step [20/500], Loss: 0.2755
# Epoch [20/50], Step [30/500], Loss: 0.2182
# Epoch [20/50], Step [40/500], Loss: 0.0816
# Epoch [20/50], Step [50/500], Loss: 0.7953
# Epoch [20/50], Step [60/500], Loss: 0.4301
# Epoch [20/50], Step [70/500], Loss: 0.0667
# Epoch [20/50], Step [80/500], Loss: 0.0701
# Epoch [20/50], Step [90/500], Loss: 0.0894
# Epoch [20/50], Step [100/500], Loss: 0.0728
# Epoch [20/50], Step [110/500], Loss: 0.1064
# Epoch [20/50], Step [120/500], Loss: 0.3914
# Epoch [20/50], Step [130/500], Loss: 0.2337
# Epoch [20/50], Step [140/500], Loss: 0.1109
# Epoch [20/50], Step [150/500], Loss: 0.2663
# Epoch [20/50], Step [160/500], Loss: 0.1760
# Epoch [20/50], Step [170/500], Loss: 0.1649
# Epoch [20/50], Step [180/500], Loss: 0.1286
# Epoch [20/50], Step [190/500], Loss: 0.1652
# Epoch [20/50], Step [200/500], Loss: 0.1146
# Epoch [20/50], Step [210/500], Loss: 0.1671
# Epoch [20/50], Step [220/500], Loss: 0.2762
# Epoch [20/50], Step [230/500], Loss: 0.0761
# Epoch [20/50], Step [240/500], Loss: 0.3351
# Epoch [20/50], Step [250/500], Loss: 0.0867
# Epoch [20/50], Step [260/500], Loss: 0.6278
# Epoch [20/50], Step [270/500], Loss: 0.0878
# Epoch [20/50], Step [280/500], Loss: 0.1043
# Epoch [20/50], Step [290/500], Loss: 0.0913
# Epoch [20/50], Step [300/500], Loss: 0.0730
# Epoch [20/50], Step [310/500], Loss: 0.6057
# Epoch [20/50], Step [320/500], Loss: 0.0719
# Epoch [20/50], Step [330/500], Loss: 0.0751
# Epoch [20/50], Step [340/500], Loss: 0.0838
# Epoch [20/50], Step [350/500], Loss: 0.0760
# Epoch [20/50], Step [360/500], Loss: 0.0970
# Epoch [20/50], Step [370/500], Loss: 0.0834
# Epoch [20/50], Step [380/500], Loss: 0.1339
# Epoch [20/50], Step [390/500], Loss: 0.4833
# Epoch [20/50], Step [400/500], Loss: 0.1374
# Epoch [20/50], Step [410/500], Loss: 0.0809
# Epoch [20/50], Step [420/500], Loss: 0.0637
# Epoch [20/50], Step [430/500], Loss: 0.0926
# Epoch [20/50], Step [440/500], Loss: 0.0821
# Epoch [20/50], Step [450/500], Loss: 0.0887
# Epoch [20/50], Step [460/500], Loss: 0.4993
# Epoch [20/50], Step [470/500], Loss: 0.5332
# Epoch [20/50], Step [480/500], Loss: 0.1892
# Epoch [20/50], Step [490/500], Loss: 0.0791
# Epoch [20/50], Step [500/500], Loss: 0.0854
# Epoch [21/50], Step [10/500], Loss: 0.1031
# Epoch [21/50], Step [20/500], Loss: 0.6091
# Epoch [21/50], Step [30/500], Loss: 0.2827
# Epoch [21/50], Step [40/500], Loss: 0.1939
# Epoch [21/50], Step [50/500], Loss: 0.1107
# Epoch [21/50], Step [60/500], Loss: 0.5240
# Epoch [21/50], Step [70/500], Loss: 0.4537
# Epoch [21/50], Step [80/500], Loss: 0.1802
# Epoch [21/50], Step [90/500], Loss: 0.2851
# Epoch [21/50], Step [100/500], Loss: 0.0542
# Epoch [21/50], Step [110/500], Loss: 0.0698
# Epoch [21/50], Step [120/500], Loss: 0.0874
# Epoch [21/50], Step [130/500], Loss: 0.0736
# Epoch [21/50], Step [140/500], Loss: 0.0728
# Epoch [21/50], Step [150/500], Loss: 0.1020
# Epoch [21/50], Step [160/500], Loss: 0.3677
# Epoch [21/50], Step [170/500], Loss: 0.3390
# Epoch [21/50], Step [180/500], Loss: 0.1003
# Epoch [21/50], Step [190/500], Loss: 0.1054
# Epoch [21/50], Step [200/500], Loss: 0.0768
# Epoch [21/50], Step [210/500], Loss: 0.3772
# Epoch [21/50], Step [220/500], Loss: 0.2720
# Epoch [21/50], Step [230/500], Loss: 0.0699
# Epoch [21/50], Step [240/500], Loss: 0.0919
# Epoch [21/50], Step [250/500], Loss: 0.0763
# Epoch [21/50], Step [260/500], Loss: 0.1025
# Epoch [21/50], Step [270/500], Loss: 0.3845
# Epoch [21/50], Step [280/500], Loss: 0.5524
# Epoch [21/50], Step [290/500], Loss: 0.1168
# Epoch [21/50], Step [300/500], Loss: 0.0913
# Epoch [21/50], Step [310/500], Loss: 0.0933
# Epoch [21/50], Step [320/500], Loss: 0.2118
# Epoch [21/50], Step [330/500], Loss: 0.0779
# Epoch [21/50], Step [340/500], Loss: 0.0949
# Epoch [21/50], Step [350/500], Loss: 0.5863
# Epoch [21/50], Step [360/500], Loss: 0.0872
# Epoch [21/50], Step [370/500], Loss: 0.0851
# Epoch [21/50], Step [380/500], Loss: 0.0968
# Epoch [21/50], Step [390/500], Loss: 0.0936
# Epoch [21/50], Step [400/500], Loss: 0.2072
# Epoch [21/50], Step [410/500], Loss: 0.2050
# Epoch [21/50], Step [420/500], Loss: 0.1901
# Epoch [21/50], Step [430/500], Loss: 0.1034
# Epoch [21/50], Step [440/500], Loss: 0.0877
# Epoch [21/50], Step [450/500], Loss: 0.1740
# Epoch [21/50], Step [460/500], Loss: 0.1052
# Epoch [21/50], Step [470/500], Loss: 0.0739
# Epoch [21/50], Step [480/500], Loss: 0.3207
# Epoch [21/50], Step [490/500], Loss: 0.3590
# Epoch [21/50], Step [500/500], Loss: 0.0656
# Epoch [22/50], Step [10/500], Loss: 0.3115
# Epoch [22/50], Step [20/500], Loss: 0.0632
# Epoch [22/50], Step [30/500], Loss: 0.0923
# Epoch [22/50], Step [40/500], Loss: 0.3330
# Epoch [22/50], Step [50/500], Loss: 0.3085
# Epoch [22/50], Step [60/500], Loss: 0.4184
# Epoch [22/50], Step [70/500], Loss: 0.1143
# Epoch [22/50], Step [80/500], Loss: 0.1046
# Epoch [22/50], Step [90/500], Loss: 0.0811
# Epoch [22/50], Step [100/500], Loss: 0.5384
# Epoch [22/50], Step [110/500], Loss: 0.0692
# Epoch [22/50], Step [120/500], Loss: 0.0819
# Epoch [22/50], Step [130/500], Loss: 0.3938
# Epoch [22/50], Step [140/500], Loss: 0.0786
# Epoch [22/50], Step [150/500], Loss: 0.0690
# Epoch [22/50], Step [160/500], Loss: 0.9907
# Epoch [22/50], Step [170/500], Loss: 0.1380
# Epoch [22/50], Step [180/500], Loss: 0.0542
# Epoch [22/50], Step [190/500], Loss: 0.1327
# Epoch [22/50], Step [200/500], Loss: 0.1316
# Epoch [22/50], Step [210/500], Loss: 0.0590
# Epoch [22/50], Step [220/500], Loss: 0.1585
# Epoch [22/50], Step [230/500], Loss: 0.1551
# Epoch [22/50], Step [240/500], Loss: 0.0871
# Epoch [22/50], Step [250/500], Loss: 0.0883
# Epoch [22/50], Step [260/500], Loss: 0.1753
# Epoch [22/50], Step [270/500], Loss: 0.0940
# Epoch [22/50], Step [280/500], Loss: 0.0782
# Epoch [22/50], Step [290/500], Loss: 0.5067
# Epoch [22/50], Step [300/500], Loss: 0.1926
# Epoch [22/50], Step [310/500], Loss: 0.0551
# Epoch [22/50], Step [320/500], Loss: 0.1362
# Epoch [22/50], Step [330/500], Loss: 0.2529
# Epoch [22/50], Step [340/500], Loss: 0.0794
# Epoch [22/50], Step [350/500], Loss: 0.0999
# Epoch [22/50], Step [360/500], Loss: 0.2455
# Epoch [22/50], Step [370/500], Loss: 0.0718
# Epoch [22/50], Step [380/500], Loss: 0.1956
# Epoch [22/50], Step [390/500], Loss: 0.0822
# Epoch [22/50], Step [400/500], Loss: 0.1051
# Epoch [22/50], Step [410/500], Loss: 0.1810
# Epoch [22/50], Step [420/500], Loss: 0.1260
# Epoch [22/50], Step [430/500], Loss: 0.0795
# Epoch [22/50], Step [440/500], Loss: 0.1951
# Epoch [22/50], Step [450/500], Loss: 0.1190
# Epoch [22/50], Step [460/500], Loss: 0.0927
# Epoch [22/50], Step [470/500], Loss: 0.0812
# Epoch [22/50], Step [480/500], Loss: 0.0667
# Epoch [22/50], Step [490/500], Loss: 0.0549
# Epoch [22/50], Step [500/500], Loss: 0.4083
# Epoch [23/50], Step [10/500], Loss: 0.1902
# Epoch [23/50], Step [20/500], Loss: 0.1702
# Epoch [23/50], Step [30/500], Loss: 0.0938
# Epoch [23/50], Step [40/500], Loss: 0.4496
# Epoch [23/50], Step [50/500], Loss: 0.6202
# ...
# Epoch [43/50], Step [380/500], Loss: 0.1028
# Epoch [43/50], Step [390/500], Loss: 0.0659
# Epoch [43/50], Step [400/500], Loss: 0.1001
# Epoch [43/50], Step [410/500], Loss: 0.1615
# Epoch [43/50], Step [420/500], Loss: 0.3955
# Epoch [43/50], Step [430/500], Loss: 0.0857
# Epoch [43/50], Step [440/500], Loss: 0.0823
# Epoch [43/50], Step [450/500], Loss: 0.0613
# Epoch [43/50], Step [460/500], Loss: 0.0817
# Epoch [43/50], Step [470/500], Loss: 0.2470
# Epoch [43/50], Step [480/500], Loss: 0.1319
# Epoch [43/50], Step [490/500], Loss: 0.1358
# Epoch [43/50], Step [500/500], Loss: 0.0615
# Epoch [44/50], Step [10/500], Loss: 0.1148
# Epoch [44/50], Step [20/500], Loss: 0.0687
# Epoch [44/50], Step [30/500], Loss: 0.0830
# Epoch [44/50], Step [40/500], Loss: 0.0835
# Epoch [44/50], Step [50/500], Loss: 0.1100
# Epoch [44/50], Step [60/500], Loss: 0.0539
# Epoch [44/50], Step [70/500], Loss: 0.0753
# Epoch [44/50], Step [80/500], Loss: 0.0899
# Epoch [44/50], Step [90/500], Loss: 0.2333
# Epoch [44/50], Step [100/500], Loss: 0.7082
# Epoch [44/50], Step [110/500], Loss: 0.1005
# Epoch [44/50], Step [120/500], Loss: 0.1046
# Epoch [44/50], Step [130/500], Loss: 0.1165
# Epoch [44/50], Step [140/500], Loss: 0.2319
# Epoch [44/50], Step [150/500], Loss: 0.0556
# Epoch [44/50], Step [160/500], Loss: 0.1007
# Epoch [44/50], Step [170/500], Loss: 0.1291
# Epoch [44/50], Step [180/500], Loss: 0.0868
# Epoch [44/50], Step [190/500], Loss: 0.0489
# Epoch [44/50], Step [200/500], Loss: 0.0905
# Epoch [44/50], Step [210/500], Loss: 0.0792
# Epoch [44/50], Step [220/500], Loss: 0.0791
# Epoch [44/50], Step [230/500], Loss: 0.4657
# Epoch [44/50], Step [240/500], Loss: 0.0986
# Epoch [44/50], Step [250/500], Loss: 0.0697
# Epoch [44/50], Step [260/500], Loss: 0.0986
# Epoch [44/50], Step [270/500], Loss: 0.0648
# Epoch [44/50], Step [280/500], Loss: 0.3166
# Epoch [44/50], Step [290/500], Loss: 0.0645
# Epoch [44/50], Step [300/500], Loss: 0.3950
# Epoch [44/50], Step [310/500], Loss: 0.2319
# Epoch [44/50], Step [320/500], Loss: 0.9453
# Epoch [44/50], Step [330/500], Loss: 0.0744
# Epoch [44/50], Step [340/500], Loss: 0.1781
# Epoch [44/50], Step [350/500], Loss: 0.1026
# Epoch [44/50], Step [360/500], Loss: 0.3017
# Epoch [44/50], Step [370/500], Loss: 0.1000
# Epoch [44/50], Step [380/500], Loss: 0.1021
# Epoch [44/50], Step [390/500], Loss: 0.2720
# Epoch [44/50], Step [400/500], Loss: 0.2366
# Epoch [44/50], Step [410/500], Loss: 0.2297
# Epoch [44/50], Step [420/500], Loss: 0.4602
# Epoch [44/50], Step [430/500], Loss: 0.4507
# Epoch [44/50], Step [440/500], Loss: 0.0730
# Epoch [44/50], Step [450/500], Loss: 0.0847
# Epoch [44/50], Step [460/500], Loss: 0.0723
# Epoch [44/50], Step [470/500], Loss: 0.0722
# Epoch [44/50], Step [480/500], Loss: 0.0930
# Epoch [44/50], Step [490/500], Loss: 0.4293
# Epoch [44/50], Step [500/500], Loss: 0.2577
# Epoch [45/50], Step [10/500], Loss: 0.1075
# Epoch [45/50], Step [20/500], Loss: 0.3705
# Epoch [45/50], Step [30/500], Loss: 0.0739
# Epoch [45/50], Step [40/500], Loss: 0.3637
# Epoch [45/50], Step [50/500], Loss: 0.0512
# Epoch [45/50], Step [60/500], Loss: 0.0841
# Epoch [45/50], Step [70/500], Loss: 0.0926
# Epoch [45/50], Step [80/500], Loss: 0.0823
# Epoch [45/50], Step [90/500], Loss: 0.1343
# Epoch [45/50], Step [100/500], Loss: 0.0778
# Epoch [45/50], Step [110/500], Loss: 0.0791
# Epoch [45/50], Step [120/500], Loss: 0.3669
# Epoch [45/50], Step [130/500], Loss: 0.1003
# Epoch [45/50], Step [140/500], Loss: 0.4735
# Epoch [45/50], Step [150/500], Loss: 0.6017
# Epoch [45/50], Step [160/500], Loss: 0.1020
# Epoch [45/50], Step [170/500], Loss: 0.0598
# Epoch [45/50], Step [180/500], Loss: 0.0740
# Epoch [45/50], Step [190/500], Loss: 0.0798
# Epoch [45/50], Step [200/500], Loss: 0.0929
# Epoch [45/50], Step [210/500], Loss: 0.1019
# Epoch [45/50], Step [220/500], Loss: 0.0868
# Epoch [45/50], Step [230/500], Loss: 0.0794
# Epoch [45/50], Step [240/500], Loss: 0.0737
# Epoch [45/50], Step [250/500], Loss: 0.0656
# Epoch [45/50], Step [260/500], Loss: 0.0573
# Epoch [45/50], Step [270/500], Loss: 0.1240
# Epoch [45/50], Step [280/500], Loss: 0.1130
# Epoch [45/50], Step [290/500], Loss: 0.4755
# Epoch [45/50], Step [300/500], Loss: 0.2637
# Epoch [45/50], Step [310/500], Loss: 0.1865
# Epoch [45/50], Step [320/500], Loss: 0.1120
# Epoch [45/50], Step [330/500], Loss: 0.1207
# Epoch [45/50], Step [340/500], Loss: 0.2908
# Epoch [45/50], Step [350/500], Loss: 0.1696
# Epoch [45/50], Step [360/500], Loss: 0.1008
# Epoch [45/50], Step [370/500], Loss: 0.1928
# Epoch [45/50], Step [380/500], Loss: 0.2057
# Epoch [45/50], Step [390/500], Loss: 0.1223
# Epoch [45/50], Step [400/500], Loss: 0.1000
# Epoch [45/50], Step [410/500], Loss: 0.1076
# Epoch [45/50], Step [420/500], Loss: 0.0804
# Epoch [45/50], Step [430/500], Loss: 0.1695
# Epoch [45/50], Step [440/500], Loss: 0.0685
# Epoch [45/50], Step [450/500], Loss: 0.0710
# Epoch [45/50], Step [460/500], Loss: 0.1568
# Epoch [45/50], Step [470/500], Loss: 0.0761
# Epoch [45/50], Step [480/500], Loss: 0.0816
# Epoch [45/50], Step [490/500], Loss: 0.1351
# Epoch [45/50], Step [500/500], Loss: 0.3763
# Epoch [46/50], Step [10/500], Loss: 0.1207
# Epoch [46/50], Step [20/500], Loss: 0.0964
# Epoch [46/50], Step [30/500], Loss: 0.0750
# Epoch [46/50], Step [40/500], Loss: 0.1335
# Epoch [46/50], Step [50/500], Loss: 0.2035
# Epoch [46/50], Step [60/500], Loss: 0.3866
# Epoch [46/50], Step [70/500], Loss: 0.0925
# Epoch [46/50], Step [80/500], Loss: 0.5960
# Epoch [46/50], Step [90/500], Loss: 0.2200
# Epoch [46/50], Step [100/500], Loss: 0.0994
# Epoch [46/50], Step [110/500], Loss: 0.0708
# Epoch [46/50], Step [120/500], Loss: 0.1129
# Epoch [46/50], Step [130/500], Loss: 0.0713
# Epoch [46/50], Step [140/500], Loss: 0.0769
# Epoch [46/50], Step [150/500], Loss: 0.0795
# Epoch [46/50], Step [160/500], Loss: 0.1876
# Epoch [46/50], Step [170/500], Loss: 0.0935
# Epoch [46/50], Step [180/500], Loss: 0.1093
# Epoch [46/50], Step [190/500], Loss: 0.0902
# Epoch [46/50], Step [200/500], Loss: 0.0836
# Epoch [46/50], Step [210/500], Loss: 0.4687
# Epoch [46/50], Step [220/500], Loss: 0.1724
# Epoch [46/50], Step [230/500], Loss: 0.1665
# Epoch [46/50], Step [240/500], Loss: 0.0920
# Epoch [46/50], Step [250/500], Loss: 0.0659
# Epoch [46/50], Step [260/500], Loss: 0.2143
# Epoch [46/50], Step [270/500], Loss: 0.0811
# Epoch [46/50], Step [280/500], Loss: 0.0618
# Epoch [46/50], Step [290/500], Loss: 0.2723
# Epoch [46/50], Step [300/500], Loss: 0.2219
# Epoch [46/50], Step [310/500], Loss: 0.0805
# Epoch [46/50], Step [320/500], Loss: 0.0832
# Epoch [46/50], Step [330/500], Loss: 0.6745
# Epoch [46/50], Step [340/500], Loss: 0.3258
# Epoch [46/50], Step [350/500], Loss: 0.2914
# Epoch [46/50], Step [360/500], Loss: 0.0528
# Epoch [46/50], Step [370/500], Loss: 0.1441
# Epoch [46/50], Step [380/500], Loss: 0.0880
# Epoch [46/50], Step [390/500], Loss: 0.2118
# Epoch [46/50], Step [400/500], Loss: 0.1271
# Epoch [46/50], Step [410/500], Loss: 0.5063
# Epoch [46/50], Step [420/500], Loss: 0.0878
# Epoch [46/50], Step [430/500], Loss: 0.1447
# Epoch [46/50], Step [440/500], Loss: 0.0867
# Epoch [46/50], Step [450/500], Loss: 0.1057
# Epoch [46/50], Step [460/500], Loss: 0.1140
# Epoch [46/50], Step [470/500], Loss: 0.1141
# Epoch [46/50], Step [480/500], Loss: 0.0798
# Epoch [46/50], Step [490/500], Loss: 0.1051
# Epoch [46/50], Step [500/500], Loss: 0.2051
# Epoch [47/50], Step [10/500], Loss: 0.4069
# Epoch [47/50], Step [20/500], Loss: 0.0594
# Epoch [47/50], Step [30/500], Loss: 0.1142
# Epoch [47/50], Step [40/500], Loss: 0.1355
# Epoch [47/50], Step [50/500], Loss: 0.0705
# Epoch [47/50], Step [60/500], Loss: 0.1206
# Epoch [47/50], Step [70/500], Loss: 0.0663
# Epoch [47/50], Step [80/500], Loss: 0.0831
# Epoch [47/50], Step [90/500], Loss: 0.0662
# Epoch [47/50], Step [100/500], Loss: 0.0626
# Epoch [47/50], Step [110/500], Loss: 0.0839
# Epoch [47/50], Step [120/500], Loss: 0.0699
# Epoch [47/50], Step [130/500], Loss: 0.2388
# Epoch [47/50], Step [140/500], Loss: 0.0780
# Epoch [47/50], Step [150/500], Loss: 0.2282
# Epoch [47/50], Step [160/500], Loss: 0.1082
# Epoch [47/50], Step [170/500], Loss: 0.2541
# Epoch [47/50], Step [180/500], Loss: 0.2227
# Epoch [47/50], Step [190/500], Loss: 0.0964
# Epoch [47/50], Step [200/500], Loss: 0.0607
# Epoch [47/50], Step [210/500], Loss: 0.2220
# Epoch [47/50], Step [220/500], Loss: 0.3962
# Epoch [47/50], Step [230/500], Loss: 0.0566
# Epoch [47/50], Step [240/500], Loss: 0.1179
# Epoch [47/50], Step [250/500], Loss: 0.1553
# Epoch [47/50], Step [260/500], Loss: 0.5318
# Epoch [47/50], Step [270/500], Loss: 0.0709
# Epoch [47/50], Step [280/500], Loss: 0.0928
# Epoch [47/50], Step [290/500], Loss: 0.0621
# Epoch [47/50], Step [300/500], Loss: 0.1828
# Epoch [47/50], Step [310/500], Loss: 0.0784
# Epoch [47/50], Step [320/500], Loss: 0.1750
# Epoch [47/50], Step [330/500], Loss: 0.0672
# Epoch [47/50], Step [340/500], Loss: 0.2073
# Epoch [47/50], Step [350/500], Loss: 0.3740
# Epoch [47/50], Step [360/500], Loss: 0.1813
# Epoch [47/50], Step [370/500], Loss: 0.0526
# Epoch [47/50], Step [380/500], Loss: 0.5769
# Epoch [47/50], Step [390/500], Loss: 0.3539
# Epoch [47/50], Step [400/500], Loss: 0.2123
# Epoch [47/50], Step [410/500], Loss: 0.2631
# Epoch [47/50], Step [420/500], Loss: 0.0881
# Epoch [47/50], Step [430/500], Loss: 0.0719
# Epoch [47/50], Step [440/500], Loss: 0.0747
# Epoch [47/50], Step [450/500], Loss: 0.0864
# Epoch [47/50], Step [460/500], Loss: 0.0594
# Epoch [47/50], Step [470/500], Loss: 0.0831
# Epoch [47/50], Step [480/500], Loss: 0.0707
# Epoch [47/50], Step [490/500], Loss: 0.2178
# Epoch [47/50], Step [500/500], Loss: 0.3376
# Epoch [48/50], Step [10/500], Loss: 0.1801
# Epoch [48/50], Step [20/500], Loss: 0.2327
# Epoch [48/50], Step [30/500], Loss: 0.2838
# Epoch [48/50], Step [40/500], Loss: 0.0691
# Epoch [48/50], Step [50/500], Loss: 0.2883
# Epoch [48/50], Step [60/500], Loss: 0.1036
# Epoch [48/50], Step [70/500], Loss: 0.6285
# Epoch [48/50], Step [80/500], Loss: 0.1633
# Epoch [48/50], Step [90/500], Loss: 0.0431
# Epoch [48/50], Step [100/500], Loss: 0.0883
# Epoch [48/50], Step [110/500], Loss: 0.2350
# Epoch [48/50], Step [120/500], Loss: 0.0745
# Epoch [48/50], Step [130/500], Loss: 0.0694
# Epoch [48/50], Step [140/500], Loss: 0.0860
# Epoch [48/50], Step [150/500], Loss: 0.0620
# Epoch [48/50], Step [160/500], Loss: 0.4340
# Epoch [48/50], Step [170/500], Loss: 0.0715
# Epoch [48/50], Step [180/500], Loss: 0.0915
# Epoch [48/50], Step [190/500], Loss: 0.2596
# Epoch [48/50], Step [200/500], Loss: 0.0761
# Epoch [48/50], Step [210/500], Loss: 0.0872
# Epoch [48/50], Step [220/500], Loss: 0.0873
# Epoch [48/50], Step [230/500], Loss: 0.0903
# Epoch [48/50], Step [240/500], Loss: 0.3015
# Epoch [48/50], Step [250/500], Loss: 0.1644
# Epoch [48/50], Step [260/500], Loss: 0.7352
# Epoch [48/50], Step [270/500], Loss: 0.3751
# Epoch [48/50], Step [280/500], Loss: 0.0955
# Epoch [48/50], Step [290/500], Loss: 0.0709
# Epoch [48/50], Step [300/500], Loss: 0.0613
# Epoch [48/50], Step [310/500], Loss: 0.0732
# Epoch [48/50], Step [320/500], Loss: 0.0881
# Epoch [48/50], Step [330/500], Loss: 0.1782
# Epoch [48/50], Step [340/500], Loss: 0.0676
# Epoch [48/50], Step [350/500], Loss: 0.1059
# Epoch [48/50], Step [360/500], Loss: 0.0872
# Epoch [48/50], Step [370/500], Loss: 0.2652
# Epoch [48/50], Step [380/500], Loss: 0.4543
# Epoch [48/50], Step [390/500], Loss: 0.3985
# Epoch [48/50], Step [400/500], Loss: 0.1655
# Epoch [48/50], Step [410/500], Loss: 0.1079
# Epoch [48/50], Step [420/500], Loss: 0.1265
# Epoch [48/50], Step [430/500], Loss: 0.0649
# Epoch [48/50], Step [440/500], Loss: 0.0731
# Epoch [48/50], Step [450/500], Loss: 0.0690
# Epoch [48/50], Step [460/500], Loss: 0.1429
# Epoch [48/50], Step [470/500], Loss: 0.1776
# Epoch [48/50], Step [480/500], Loss: 0.3733
# Epoch [48/50], Step [490/500], Loss: 0.2118
# Epoch [48/50], Step [500/500], Loss: 0.2167
# Epoch [49/50], Step [10/500], Loss: 0.2138
# Epoch [49/50], Step [20/500], Loss: 0.0846
# Epoch [49/50], Step [30/500], Loss: 0.0610
# Epoch [49/50], Step [40/500], Loss: 0.1043
# Epoch [49/50], Step [50/500], Loss: 0.3989
# Epoch [49/50], Step [60/500], Loss: 0.0736
# Epoch [49/50], Step [70/500], Loss: 0.1097
# Epoch [49/50], Step [80/500], Loss: 0.0585
# Epoch [49/50], Step [90/500], Loss: 0.2868
# Epoch [49/50], Step [100/500], Loss: 0.0902
# Epoch [49/50], Step [110/500], Loss: 0.0691
# Epoch [49/50], Step [120/500], Loss: 0.1775
# Epoch [49/50], Step [130/500], Loss: 0.6771
# Epoch [49/50], Step [140/500], Loss: 0.0682
# Epoch [49/50], Step [150/500], Loss: 0.3202
# Epoch [49/50], Step [160/500], Loss: 0.1117
# Epoch [49/50], Step [170/500], Loss: 0.1231
# Epoch [49/50], Step [180/500], Loss: 0.2741
# Epoch [49/50], Step [190/500], Loss: 0.6629
# Epoch [49/50], Step [200/500], Loss: 0.0638
# Epoch [49/50], Step [210/500], Loss: 0.2125
# Epoch [49/50], Step [220/500], Loss: 0.2874
# Epoch [49/50], Step [230/500], Loss: 0.1283
# Epoch [49/50], Step [240/500], Loss: 0.0608
# Epoch [49/50], Step [250/500], Loss: 0.4250
# Epoch [49/50], Step [260/500], Loss: 0.0618
# Epoch [49/50], Step [270/500], Loss: 0.0651
# Epoch [49/50], Step [280/500], Loss: 0.0897
# Epoch [49/50], Step [290/500], Loss: 0.0706
# Epoch [49/50], Step [300/500], Loss: 0.0752
# Epoch [49/50], Step [310/500], Loss: 0.8045
# Epoch [49/50], Step [320/500], Loss: 0.1633
# Epoch [49/50], Step [330/500], Loss: 0.0780
# Epoch [49/50], Step [340/500], Loss: 0.0666
# Epoch [49/50], Step [350/500], Loss: 0.0585
# Epoch [49/50], Step [360/500], Loss: 0.0838
# Epoch [49/50], Step [370/500], Loss: 0.0812
# Epoch [49/50], Step [380/500], Loss: 0.0829
# Epoch [49/50], Step [390/500], Loss: 0.1333
# Epoch [49/50], Step [400/500], Loss: 0.2839
# Epoch [49/50], Step [410/500], Loss: 0.0601
# Epoch [49/50], Step [420/500], Loss: 0.0662
# Epoch [49/50], Step [430/500], Loss: 0.0598
# Epoch [49/50], Step [440/500], Loss: 0.0832
# Epoch [49/50], Step [450/500], Loss: 0.1526
# Epoch [49/50], Step [460/500], Loss: 0.1533
# Epoch [49/50], Step [470/500], Loss: 0.0772
# Epoch [49/50], Step [480/500], Loss: 0.2351
# Epoch [49/50], Step [490/500], Loss: 0.0801
# Epoch [49/50], Step [500/500], Loss: 0.0875
# Epoch [50/50], Step [10/500], Loss: 0.0904
# Epoch [50/50], Step [20/500], Loss: 0.1275
# Epoch [50/50], Step [30/500], Loss: 0.2438
# Epoch [50/50], Step [40/500], Loss: 0.4755
# Epoch [50/50], Step [50/500], Loss: 0.5350
# Epoch [50/50], Step [60/500], Loss: 0.2946
# Epoch [50/50], Step [70/500], Loss: 0.0586
# Epoch [50/50], Step [80/500], Loss: 0.3168
# Epoch [50/50], Step [90/500], Loss: 0.0848
# Epoch [50/50], Step [100/500], Loss: 0.0686
# Epoch [50/50], Step [110/500], Loss: 0.0811
# Epoch [50/50], Step [120/500], Loss: 0.0441
# Epoch [50/50], Step [130/500], Loss: 0.1167
# Epoch [50/50], Step [140/500], Loss: 0.0775
# Epoch [50/50], Step [150/500], Loss: 0.2687
# Epoch [50/50], Step [160/500], Loss: 0.0865
# Epoch [50/50], Step [170/500], Loss: 0.0677
# Epoch [50/50], Step [180/500], Loss: 0.1307
# Epoch [50/50], Step [190/500], Loss: 0.2211
# Epoch [50/50], Step [200/500], Loss: 0.3596
# Epoch [50/50], Step [210/500], Loss: 0.0876
# Epoch [50/50], Step [220/500], Loss: 0.0913
# Epoch [50/50], Step [230/500], Loss: 0.4214
# Epoch [50/50], Step [240/500], Loss: 0.0907
# Epoch [50/50], Step [250/500], Loss: 0.1943
# Epoch [50/50], Step [260/500], Loss: 0.0764
# Epoch [50/50], Step [270/500], Loss: 0.0831
# Epoch [50/50], Step [280/500], Loss: 0.0701
# Epoch [50/50], Step [290/500], Loss: 0.0888
# Epoch [50/50], Step [300/500], Loss: 0.1916
# Epoch [50/50], Step [310/500], Loss: 0.0737
# Epoch [50/50], Step [320/500], Loss: 0.5427
# Epoch [50/50], Step [330/500], Loss: 0.1148
# Epoch [50/50], Step [340/500], Loss: 0.0836
# Epoch [50/50], Step [350/500], Loss: 0.1081
# Epoch [50/50], Step [360/500], Loss: 0.2489
# Epoch [50/50], Step [370/500], Loss: 0.1925
# Epoch [50/50], Step [380/500], Loss: 0.0639
# Epoch [50/50], Step [390/500], Loss: 0.1700
# Epoch [50/50], Step [400/500], Loss: 0.2876
# Epoch [50/50], Step [410/500], Loss: 0.1566
# Epoch [50/50], Step [420/500], Loss: 0.2317
# Epoch [50/50], Step [430/500], Loss: 0.2210
# Epoch [50/50], Step [440/500], Loss: 0.1610
# Epoch [50/50], Step [450/500], Loss: 0.0518
# Epoch [50/50], Step [460/500], Loss: 1.1050
# Epoch [50/50], Step [470/500], Loss: 0.3044
# Epoch [50/50], Step [480/500], Loss: 0.1314
# Epoch [50/50], Step [490/500], Loss: 0.1145
# Epoch [50/50], Step [500/500], Loss: 0.0761
# Model saved to './models/terrain/turbo_heightmap_unet_model.pth'

# %%
def test_model(model, dataloader, device, save_output=False, output_dir='test_outputs'):
    model.eval()
    os.makedirs(output_dir, exist_ok=True)
    
    with torch.no_grad():
        for idx, (height, terrain, segmentation) in enumerate(dataloader):
            images = segmentation
            correct_image = height  # Use heightmap as the correct image
            images = images.to(device)

            outputs = model(images)

            # If using sigmoid or BCE/MSE outputs
            # outputs = torch.sigmoid(outputs)
            # Move to CPU and convert to numpy
            inputs_np = images.cpu().permute(0, 2, 3, 1).numpy()
            # outputs_np = outputs.cpu().permute(0, 2, 3, 1).clamp(0,1).numpy()
            outputs_np = outputs.cpu().permute(0, 2, 3, 1).numpy()
            correct_image_np = correct_image.cpu().permute(0, 2, 3, 1).numpy()

            for i in range(min(8, images.size(0))):  # Show/save up to 4 samples
                fig, axs = plt.subplots(1, 3, figsize=(8, 4))
                axs[0].imshow(inputs_np[i])
                axs[0].set_title("Input")
                axs[1].imshow(outputs_np[i])
                axs[1].set_title("Output")
                axs[2].imshow(correct_image_np[i])
                axs[2].set_title("Correct Image")
                for ax in axs:
                    ax.axis("off")
                plt.tight_layout()

                if save_output:
                    plt.savefig(f"{output_dir}/sample_{idx}_{i}.png")
                    plt.close()
                else:
                    plt.show()
            
            break  # only first batch for quick test
        
test_model(unet_model,test_loader, device)

# %%
import cv2
import numpy as np

def get_model_predictions_cv2(model, dataloader, device, max_batches=1, index=0):
    """
    Returns input and output image batches from model evaluation (first N batches),
    converted to OpenCV BGR image arrays.

    Returns:
        List of tuples: [(input_cv2_image, output_cv2_image), ...]
    """
    model.eval()
    predictions = []

    with torch.no_grad():
        for count, (_, _, segmentation) in enumerate(dataloader):
            if(count < index):
                continue
            inputs = segmentation.to(device)

            outputs = model(inputs)
            # print(f"outputs {outputs}")
            outputs = outputs/65535.0
            # outputs = torch.sigmoid(outputs)  # if using BCE/MSE

            # Move tensors to CPU and convert to [H, W, C] NumPy format
            inputs_np = inputs.detach().cpu().permute(0, 2, 3, 1).clamp(0, 1).numpy()
            outputs_np = outputs.detach().cpu().permute(0, 2, 3, 1).clamp(0, 1).numpy()

            # Convert each image to OpenCV (BGR, uint8)
            for inp, out in zip(inputs_np, outputs_np):
                inp_bgr = cv2.cvtColor((inp * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
                out_bgr = cv2.cvtColor((out * 255).astype(np.uint8), cv2.COLOR_RGB2BGR)
                predictions.append((inp_bgr, out_bgr))

            if max_batches is not None:
                max_batches -= 1
                if max_batches <= 0:
                    break

    return predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.widgets import Slider


predictions = get_model_predictions_cv2(unet_model, test_loader, device, max_batches=1, index=3)
print(f"got {len(predictions)} predictions")
input_img, output_img = predictions[0]  # Get first batch input and output
# Read heightmap (grayscale) and normal map images
# heightmap = cv2.imread('path_to_heightmap.png', 0)
# normal_map = cv2.imread('path_to_normal_map.png')
# Assume you’ve obtained heightmap and normal_map from your model
heightmap = output_img
normal_map = input_img
heightmap = cv2.bilateralFilter(heightmap, d=9, sigmaColor=75, sigmaSpace=75)
normal_map = cv2.bilateralFilter(normal_map, d=9, sigmaColor=75, sigmaSpace=75)

# print(f"heightmap {heightmap}")

# Convert heightmap to grayscale if it's in BGR
if len(heightmap.shape) == 3:
    heightmap_gray = cv2.cvtColor(heightmap, cv2.COLOR_BGR2GRAY)
    print(f"Converted heightmap to grayscale with shape: {heightmap_gray.shape}")
else:
    heightmap_gray = heightmap

# Convert normal map BGR → RGB (for correct colors in matplotlib)
normal_map_rgb = cv2.cvtColor(normal_map, cv2.COLOR_BGR2RGB)

# Show the images for verification
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.imshow(heightmap_gray, cmap='gray')
plt.title("2D Heightmap")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(normal_map_rgb)
plt.title("2D Normal Map (RGB)")
plt.axis("off")
plt.show()

# Prepare for 3D plotting
rows, cols = heightmap_gray.shape

# Create coordinate grids
X, Y = np.meshgrid(np.arange(cols), np.arange(rows))
Z = heightmap_gray.astype(np.float32)

# Transpose all for correct alignment if needed
Z = Z.T
normal_map_facecolors = normal_map_rgb.transpose(1, 0, 2) / 255.0  # Normalize and transpose to match Z

# Create 3D plot
fig = plt.figure(figsize=(10, 8))
plt.subplots_adjust(bottom=0.25)  # Add extra space at the bottom for sliders

ax_elev = plt.axes([0.1, 0.15, 0.8, 0.03])
ax_azim = plt.axes([0.1, 0.1, 0.8, 0.03])
slider_elev = Slider(ax_elev, 'Elevation', valmin=0, valmax=90, valinit=30)
slider_azim = Slider(ax_azim, 'Azimuth', valmin=0, valmax=360, valinit=45)
def update():
    elev = slider_elev.val
    azim = slider_azim.val
    ax.view_init(elev=elev, azim=azim)
    fig.canvas.draw_idle()

slider_elev.on_changed(update)
slider_azim.on_changed(update)
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, facecolors=normal_map_facecolors, rstride=1, cstride=1, linewidth=0, antialiased=False)
# ax.mouse_init(rotate_btn=None, zoom_btn=None) 
# ax.view_init(elev=30, azim=45)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
# plt.title("3D Surface with Normal Map Colors")
ax.set_title("3D Surface with Normal Map Colors")

# Add sliders
# Update function

plt.show()
# Convert heightmap to grayscale if not already
# Out:
# got 8 predictions
# Converted heightmap to grayscale with shape: (128, 128)
